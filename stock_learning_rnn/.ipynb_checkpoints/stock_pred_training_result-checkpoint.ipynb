# %%
import zipfile

# %%
fantasy_zip = zipfile.ZipFile('./Stock_Dataset(2017_07_06).zip')
fantasy_zip.extractall('./data')

# %%
import pandas as pd
from pandas import Series, DataFrame
from sklearn import preprocessing
import numpy as np
import tensorflow as tf
import math
#import matplotlib.pyplot as plt
#import itertools

# %%
# !pip install xlrd

# %%
# !pip install openpyxl

# %%
### 메소드 정의 
# 상세 데이터를 가져온다.
def get_stock_datail(comp_code) :
    code = format(comp_code, "06d");
    return pd.read_csv('./data/' + code + '.csv')

# matrix 데이터로 변경한다.
def to_ndarray(cols_data) :
    if isinstance(cols_data, Series):
        return np.reshape(list(cols_data), (-1,1))
    elif isinstance(cols_data, DataFrame):
        return cols_data.as_matrix()

# 컬럼을 스케일링을 시킨다.
def get_scaled_cols(data, column_name) :
    scale_data = to_ndarray(data[column_name])
    scaler = preprocessing.MinMaxScaler()
    return scaler.fit_transform(scale_data);

# 데이터를 스케일링 시킨다.
def get_scaled_data(data) :
    scaled_data = data.copy()
    scaled_data['Close'] = get_scaled_cols(scaled_data, 'Close')
    scaled_data['Open'] = get_scaled_cols(scaled_data, 'Open')
    scaled_data['High'] = get_scaled_cols(scaled_data, 'High')
    scaled_data['Low'] = get_scaled_cols(scaled_data, 'Low')
    scaled_data['Volume'] = get_scaled_cols(scaled_data, 'Volume')
    return scaled_data;

# RNN을 위한 데이터로 만든다. 
def get_dataXY(data, train_params) :
    x = to_ndarray(data[['Open', 'High', 'Low', 'Volume', 'Close']])
    y = to_ndarray(data['Close'])
    
    dataX = []
    dataY = []
    seq_length = train_params['seq_length']
    for i in range(0, len(y) - seq_length):
        _x = x[i:i + seq_length]
        _y = y[i + seq_length] # Next close price
        #print(_x, "->", _y)
        dataX.append(_x)
        dataY.append(_y)
    return dataX, dataY, y

# train 및 test 데이터로 나눈다.
def split_train_test(dataX, dataY, train_params, data, y) :
    invest_count = train_params['invest_count']
    seq_length = train_params['seq_length']
    data_count = len(dataY);
    train_size = int(data_count * train_params['train_percent'] / 100)
    train_last = data_count-invest_count;
    
    trainX = np.array(dataX[0:train_size])
    testX = np.array(dataX[train_size:train_last])
    investX = np.array(dataX[train_last:data_count])
    
    trainY = np.array(dataY[0:train_size])
    testY = np.array(dataY[train_size:train_last])
    investY = np.array(dataY[train_last:data_count])
    
    trainCloses = np.array( y[seq_length-1:train_size+seq_length-1])
    testCloses = np.array(dataY[train_size-1:train_last-1])
    investCloses = np.array(dataY[train_last-1:data_count-1])
    investRealCloses = np.array(data['Close'][train_last-1+seq_length:data_count-1+seq_length].values)
    
    return {
        'trainX': trainX, 'trainY': trainY, 'trainCloses': trainCloses,
        'testX': testX, 'testY': testY, 'testCloses' : testCloses,
        'investX': investX,'investY': investY, 'investCloses': investCloses, 'investRealCloses': investRealCloses
    }

# train, test데이터로 만든다.
def get_train_test(data, train_params) :
    scaled_data = get_scaled_data(data)
    dataX, dataY, y = get_dataXY(scaled_data, train_params)
    return split_train_test(dataX, dataY, train_params, data, y)

# 텐스플로우 변수관계 그래프롤 그린다.
def draw_graph(train_params) :
    seq_length = train_params['seq_length']
    data_dim = train_params['data_dim']
    hidden_dims = train_params['hidden_dims']
    
    tf.reset_default_graph()
    X = tf.placeholder(tf.float32, [None, seq_length, data_dim])
    X_closes = tf.placeholder(tf.float32, [None, 1])
    Y = tf.placeholder(tf.float32, [None, 1])
    output_keep_prob = tf.placeholder(tf.float32)
    
    cells = []
    for n in hidden_dims :
        cell = tf.contrib.rnn.BasicLSTMCell(num_units=n, activation=tf.tanh)
        dropout_cell = tf.contrib.rnn.DropoutWrapper(cell, output_keep_prob=output_keep_prob)
        cells.append(dropout_cell)
    stacked_rnn_cell = tf.nn.rnn_cell.MultiRNNCell(cells)
    outputs, _states = tf.nn.dynamic_rnn(stacked_rnn_cell, X, dtype=tf.float32) 
    Y_pred = tf.contrib.layers.fully_connected(
        outputs[:, -1], train_params['output_dim'], activation_fn=None)  # We use the last cell's output

    # cost/loss
    not_equal = tf.cast(tf.not_equal(tf.sign(X_closes-Y), tf.sign(X_closes-Y_pred)), tf.float32)
    loss = tf.reduce_sum(tf.square(Y_pred - Y) + not_equal)
        
    optimizer = tf.train.AdamOptimizer(train_params['learning_rate'])
    train = optimizer.minimize(loss)

    # RMSE
    targets = tf.placeholder(tf.float32, [None, 1])
    predictions = tf.placeholder(tf.float32, [None, 1])
    rmse = tf.sqrt(tf.reduce_mean(tf.square(targets - predictions)))
    direction_error = tf.reduce_mean(
        tf.cast(tf.not_equal(tf.sign(X_closes-targets), tf.sign(X_closes-predictions)), tf.float32))
    
    return {
        'X': X,
        'Y': Y,
        'output_keep_prob': output_keep_prob,
        'train': train,
        'loss' : loss,
        'Y_pred': Y_pred,
        'targets': targets,
        'rmse' : rmse,
        'predictions': predictions,
        'X_closes' : X_closes,
        'direction_error' : direction_error
    }

def draw_plot(rmse_vals, test_predict, testY, train_params, comp_name) :
    
    print('rmse_vals : ', rmse_vals[len(rmse_vals)-1])
    plt.figure(1)
    plt.plot(rmse_vals, 'gold')
    plt.xlabel('Epoch(x100)')
    plt.ylabel('Root Mean Square Error')
    plt.title(comp_name)

    plt.figure(2)
    plt.plot(testY, 'r')
    plt.plot(test_predict, 'b')
    plt.xlabel('Time Period')
    plt.ylabel('Stock Price')
    plt.title(comp_name)
    plt.show()

# 학습을 시킨다.
def let_training(data_params, train_params, graph_params, comp_code, comp_name) :
    X = graph_params['X']
    Y = graph_params['Y']
    output_keep_prob = graph_params['output_keep_prob']
    train = graph_params['train']
    loss = graph_params['loss']
    trainX = data_params['trainX']
    trainY = data_params['trainY']
    testX = data_params['testX']
    testY = data_params['testY']
    trainCloses = data_params['trainCloses']
    testCloses = data_params['testCloses']
    
    Y_pred = graph_params['Y_pred']
    targets = graph_params['targets']
    rmse = graph_params['rmse']
    predictions = graph_params['predictions']
    X_closes = graph_params['X_closes']
    direction_error = graph_params['direction_error']
    loss_up_count = train_params['loss_up_count']
    dropout_keep = train_params['dropout_keep']
    
    saver = tf.train.Saver()
    
    with tf.Session() as sess:
        init = tf.global_variables_initializer()
        sess.run(init)

        # Training step
        min_rmse_val = 999999
        min_direction_error_val = 999999
        less_cnt = 0
        train_count = 0
        rmse_vals = []
        
        for i in range(train_params['iterations']):
            _, step_loss = sess.run([train, loss], feed_dict={X: trainX, Y: trainY, X_closes: trainCloses, output_keep_prob: dropout_keep})
            if i % 100 == 0 :
                test_predict = sess.run(Y_pred, feed_dict={X: testX, output_keep_prob: 1.0})
                rmse_val, direction_error_val = sess.run([rmse,  direction_error], feed_dict={targets: testY, predictions: test_predict, X_closes: testCloses}) 
                #print(step_loss, rmse_val, direction_error_val)
                #if rmse_val < min_rmse_val :
                rmse_vals.append(rmse_val)
                if direction_error_val + rmse_val < min_direction_error_val + min_rmse_val :
                #if direction_error_val < min_direction_error_val :
                    tf.add_to_collection("X", X)
                    tf.add_to_collection("X_closes", X_closes)
                    tf.add_to_collection("Y", Y)
                    tf.add_to_collection("train", train)
                    tf.add_to_collection("Y_pred", Y_pred)
                    tf.add_to_collection("output_keep_prob", output_keep_prob)
                    saver.save(sess, "./sessions/" + str(comp_code) + ".ckpt")
                    less_cnt = 0
                    train_count = i;
                    max_test_predict, min_rmse_val, min_direction_error_val = test_predict, rmse_val, direction_error_val
                else :
                    less_cnt += 1
                if less_cnt > loss_up_count :
                    break
        #draw_plot(rmse_vals, max_test_predict, testY, train_params, comp_name) 
        return max_test_predict, min_rmse_val, min_direction_error_val, train_count 

# 그래프를 그리고 학습을 시킨다.    
def let_leaning(data_params, train_params, comp_code, comp_name):
    graph_params = draw_graph(train_params)
    return let_training(data_params, train_params, graph_params, comp_code, comp_name)

def to_dataFrame(data, columns) :
    return pd.DataFrame(data, columns=columns)

# excel로 저장한다.
def save_excel(df_data, file_name):
    writer = pd.ExcelWriter(file_name)
    df_data.to_excel(writer,'Sheet1', index=False)
    writer.save()

# 예측 값에 따라 매수 매도를 실행한다.    
def let_invest_money(invest_predict, now_scaled_close, now_close, train_params, now_money, now_stock_cnt) :
    seq_length = train_params['seq_length']
    data_dim = train_params['data_dim']
    fee_percent = train_params['fee_percent']
    invest_min_percent = train_params['invest_min_percent']
    
    ratio = (invest_predict - now_scaled_close) /now_scaled_close * 100
    
    if ratio > invest_min_percent :
        cnt = math.floor(now_money/now_close)
        if cnt > 0 :
            fee = now_close * fee_percent/100
            now_money -= (now_close + fee) * cnt
            now_stock_cnt += cnt
    elif ratio < -invest_min_percent :
        if now_stock_cnt > 0 :
            now_money += to_money(now_close, now_stock_cnt, train_params)
            now_stock_cnt = 0
    #print(now_money, now_stock_cnt, now_scaled_close, invest_predict, data_params['testY'])
    return now_money, now_stock_cnt

# 주식매도를 해서 돈으로 바꾼다.
def to_money(now_stock_cnt, now_close, train_params) :
    money = 0
    if now_stock_cnt > 0 :
        fee_percent = train_params['fee_percent'] 
        tax_percent = train_params['tax_percent']
        
        fee = now_close * fee_percent/100
        tax = now_close * tax_percent/100
        money = (now_close - (fee + tax)) * now_stock_cnt
    return money
    
# 학습 후 모의 주식 거래를 한다.
def let_invest(row, train_params, data_params, train_cnt):
    comp_code = row['종목코드']
    invest_count = train_params['invest_count']
    invest_money = train_params['invest_money']
    dropout_keep = train_params['dropout_keep']
    
    investX = data_params['investX']
    investCloses = data_params['investCloses']
    investRealCloses = data_params['investRealCloses']
    investX = data_params['investX']
    investY = data_params['investY']
    testX = data_params['testX']
    testY = data_params['testY']
    testCloses = data_params['testCloses']
    #print(investRealCloses)
    
    now_stock_cnt = 0
    saver = tf.train.Saver()
    with tf.Session() as sess:
        init = tf.global_variables_initializer()
        sess.run(init)
        
        saver.restore(sess, "./sessions/" + str(comp_code) + ".ckpt") 
        X = tf.get_collection('X')[0]
        X_closes = tf.get_collection('X_closes')[0]
        Y = tf.get_collection('Y')[0]
        train = tf.get_collection('train')[0]
        Y_pred = tf.get_collection('Y_pred')[0]
        output_keep_prob = tf.get_collection('output_keep_prob')[0]
        
        for i in range(int(train_cnt/10)):
            sess.run(train, feed_dict={X: testX, Y: testY, X_closes: testCloses, output_keep_prob: dropout_keep})
        
        for i in range(invest_count) :
            np.array([1, 2, 3], ndmin=2)
            invest_predicts = sess.run(Y_pred, feed_dict={X: investX[i:i+1], output_keep_prob: 1.0})
            
            invest_predict = invest_predicts[0][0];
            now_scaled_close = investCloses[0][0]
            now_close = investRealCloses[i]
            #print(invest_predict, now_scaled_close, now_close)
            invest_money, now_stock_cnt = let_invest_money(invest_predict, now_scaled_close, now_close,
                                                           train_params, invest_money, now_stock_cnt)
            for i in range(int(train_cnt/100)):
                sess.run(train, feed_dict={X: investX[i:i+1], Y: investY[i:i+1], X_closes: investCloses[i:i+1], 
                                           output_keep_prob: dropout_keep})
            #break
        invest_money += to_money(now_stock_cnt, now_close, train_params)
    #print(now_money)
    return invest_money

# %%
# 파라미터 정의 
# train Parameters
train_params = {
    'seq_length' : 5, # 시퀀스 갯수
    'data_dim' : 5,    # 입력 데이터 갯수
    'hidden_dims' : [128, 96, 64],  # 히든 레이어 갯수 
    'dropout_keep' : 0.8, # dropout 
    'output_dim' : 1,  # 출력 데이터 갯수
    'learning_rate' : 0.0001, 
    'iterations' : 100000,  # 최대 훈련 반복횟수
    'train_percent' : 70.0, # 훈련 데이터 퍼센트
    'loss_up_count' : 10, # early stopping
    #'invest_corp_count' : 100, # 투자하는 주식회사 갯수
    'invest_count' : 50,  # 투자 횟수
    'invest_money' : 1000000, # 각 주식에 모의투자할 금액
    'fee_percent' : 0.015, # 투자시 발생하는 수수료
    'tax_percent' : 0.5,   # 매도시 발생하는 세금
    'invest_min_percent' : 0.6 # 투자를 하는 최소 간격 퍼센트 
};

# %%
# 주식회사 데이터
corporations = pd.read_excel('./corporations.xlsx')

# %%
stock_corps = corporations.query("상장일<'2005-01-01'  ")[['회사명', '종목코드']]
print(len(stock_corps))
# Out:
# 1068

# %%
# 주식 종목들을 가져와서 학습을 시킨다.
comp_rmses = []
no = 1;
print('no', 'code', 'name', 'rmse', 'direction_error', 'invest_result')
for idx, row in stock_corps.iterrows():
    if no < 581 :
        no += 1
        continue
    comp_code = row['종목코드']
    data = get_stock_datail(comp_code)
    data_params = get_train_test(data, train_params)
    _, rmse_val, direction_error_val, train_cnt = let_leaning(data_params, train_params, comp_code, row['회사명'])
    
    now_money = let_invest(row, train_params, data_params, train_cnt)
    print(no, comp_code, row['회사명'], rmse_val, direction_error_val, now_money)
    comp_rmses.append([comp_code, row['회사명'], rmse_val, direction_error_val, now_money])
    no += 1
    #break
# Out:
# no code name rmse direction_error invest_result
# /opt/venv/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /opt/venv/lib/python3.6/site-packages/ipykernel_launcher.py:12: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if sys.path[0] == '':
# INFO:tensorflow:Restoring parameters from ./sessions/7540.ckpt
# 581 7540 샘표 0.0638629 0.50584114 988300.1449999998
# INFO:tensorflow:Restoring parameters from ./sessions/21050.ckpt
# 582 21050 서원 0.00762933 0.50934577 1064064.5459999999
# INFO:tensorflow:Restoring parameters from ./sessions/2420.ckpt
# 583 2420 세기상사 0.051123112 0.49182242 953856.7600000001
# INFO:tensorflow:Restoring parameters from ./sessions/21820.ckpt
# 584 21820 세원정공 0.006352797 0.49415886 1021566.25
# INFO:tensorflow:Restoring parameters from ./sessions/34300.ckpt
# 585 34300 신세계건설 0.036346693 0.49415886 977838.6174999998
# INFO:tensorflow:Restoring parameters from ./sessions/11090.ckpt
# 586 11090 에넥스 0.02765425 0.4661215 945565.9265
# INFO:tensorflow:Restoring parameters from ./sessions/5850.ckpt
# 587 5850 에스엘 0.030813184 0.5046729 1098172.88
# INFO:tensorflow:Restoring parameters from ./sessions/4250.ckpt
# 588 4250 엔피씨 0.012690372 0.5140187 973411.354
# INFO:tensorflow:Restoring parameters from ./sessions/4720.ckpt
# 589 4720 우리들제약 0.025603667 0.47780374 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/2920.ckpt
# 590 2920 유성기업 0.027989503 0.50233644 948817.4295
# INFO:tensorflow:Restoring parameters from ./sessions/760.ckpt
# 591 760 이화산업 0.04577379 0.48948598 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/7570.ckpt
# 592 7570 일양약품 0.026354251 0.47429907 935993.9800000002
# INFO:tensorflow:Restoring parameters from ./sessions/81000.ckpt
# 593 81000 일진다이아 0.05392877 0.47429907 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/2600.ckpt
# 594 2600 조흥 0.02394907 0.5432243 1253015.6
# INFO:tensorflow:Restoring parameters from ./sessions/51630.ckpt
# 595 51630 진양화학 0.010806621 0.49766356 930508.83875
# INFO:tensorflow:Restoring parameters from ./sessions/2780.ckpt
# 596 2780 진흥기업 0.028392546 0.52803737 1185595.1305000002
# INFO:tensorflow:Restoring parameters from ./sessions/650.ckpt
# 597 650 천일고속 0.037426654 0.48948598 1032901.7999999999
# INFO:tensorflow:Restoring parameters from ./sessions/29460.ckpt
# 598 29460 케이씨 0.02831398 0.51285046 1375556.67
# INFO:tensorflow:Restoring parameters from ./sessions/31820.ckpt
# 599 31820 콤텍시스템 0.050032504 0.49766356 951132.7779999999
# INFO:tensorflow:Restoring parameters from ./sessions/5740.ckpt
# 600 5740 크라운해태홀딩스 0.04893591 0.5186916 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/5490.ckpt
# 601 5490 포스코 0.01360587 0.53154206 1059811.225
# INFO:tensorflow:Restoring parameters from ./sessions/17810.ckpt
# 602 17810 풀무원 0.05054744 0.49766356 921610.3250000001
# INFO:tensorflow:Restoring parameters from ./sessions/4090.ckpt
# 603 4090 한국석유공업 0.013958822 0.5385514 967395.4
# INFO:tensorflow:Restoring parameters from ./sessions/2000.ckpt
# 604 2000 한국유리공업 0.019354764 0.5070093 1150937.4500000002
# INFO:tensorflow:Restoring parameters from ./sessions/7280.ckpt
# 605 7280 한국특수형강 0.029025411 0.6448598 1250062.762
# INFO:tensorflow:Restoring parameters from ./sessions/10100.ckpt
# 606 10100 한국프랜지공업 0.03819415 0.5 1039950.57
# INFO:tensorflow:Restoring parameters from ./sessions/1750.ckpt
# 607 1750 한양증권 0.010260323 0.5035047 1107549.91
# INFO:tensorflow:Restoring parameters from ./sessions/3300.ckpt
# 608 3300 한일시멘트 0.041019216 0.50584114 975036.2
# INFO:tensorflow:Restoring parameters from ./sessions/5110.ckpt
# 609 5110 한창 0.0650817 0.5070093 924853.903
# INFO:tensorflow:Restoring parameters from ./sessions/10620.ckpt
# 610 10620 현대미포조선 0.011529917 0.48014018 1094503.0
# INFO:tensorflow:Restoring parameters from ./sessions/1500.ckpt
# 611 1500 현대차투자증권 0.011056569 0.5385514 1153148.6775
# INFO:tensorflow:Restoring parameters from ./sessions/68790.ckpt
# 612 68790 DMS 0.03396517 0.5035047 898451.52
# INFO:tensorflow:Restoring parameters from ./sessions/46440.ckpt
# 613 46440 KG모빌리언스 0.03855121 0.48714954 970903.5900000001
# INFO:tensorflow:Restoring parameters from ./sessions/36540.ckpt
# 614 36540 SFA반도체 0.026265966 0.5303738 1042753.375
# INFO:tensorflow:Restoring parameters from ./sessions/57500.ckpt
# 615 57500 SKC 솔믹스 0.07490943 0.47429907 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/48550.ckpt
# 616 48550 SM C&C 0.028012207 0.4567757 1226316.3097499998
# INFO:tensorflow:Restoring parameters from ./sessions/32540.ckpt
# 617 32540 TJ미디어 0.02667447 0.47897196 962491.2400000001
# INFO:tensorflow:Restoring parameters from ./sessions/39240.ckpt
# 618 39240 경남스틸 0.02870497 0.5198598 1033726.21
# INFO:tensorflow:Restoring parameters from ./sessions/11040.ckpt
# 619 11040 경동제약 0.016135572 0.50584114 921016.1099999999
# INFO:tensorflow:Restoring parameters from ./sessions/51490.ckpt
# 620 51490 나라엠앤디 0.04510879 0.5116823 1003161.4907499999
# INFO:tensorflow:Restoring parameters from ./sessions/33640.ckpt
# 621 33640 네패스 0.018447092 0.49649534 844000.768
# INFO:tensorflow:Restoring parameters from ./sessions/48470.ckpt
# 622 48470 대동스틸 0.03496793 0.47313085 1221660.44925
# INFO:tensorflow:Restoring parameters from ./sessions/7720.ckpt
# 623 7720 대명코퍼레이션 0.005339768 0.5151869 1665303.1745
# INFO:tensorflow:Restoring parameters from ./sessions/25440.ckpt
# 624 25440 대성엘텍 0.017306192 0.5116823 1122936.9102500002
# INFO:tensorflow:Restoring parameters from ./sessions/67080.ckpt
# 625 67080 대화제약 0.050377294 0.52453274 869348.9
# INFO:tensorflow:Restoring parameters from ./sessions/75970.ckpt
# 626 75970 동국알앤에스 0.05659844 0.510514 1001076.3602499999
# INFO:tensorflow:Restoring parameters from ./sessions/32960.ckpt
# 627 32960 동일기연 0.038162827 0.5151869 1038494.6
# INFO:tensorflow:Restoring parameters from ./sessions/5290.ckpt
# 628 5290 동진쎄미켐 0.028443525 0.52219623 1249604.95
# INFO:tensorflow:Restoring parameters from ./sessions/33130.ckpt
# 629 33130 디지틀조선 0.050528433 0.4848131 936729.45175
# INFO:tensorflow:Restoring parameters from ./sessions/42500.ckpt
# 630 42500 링네트 0.053596698 0.49182242 942657.716
# INFO:tensorflow:Restoring parameters from ./sessions/44480.ckpt
# 631 44480 바이오제네틱스 0.04972707 0.49649534 951756.3999999999
# INFO:tensorflow:Restoring parameters from ./sessions/36620.ckpt
# 632 36620 버추얼텍 0.055270497 0.49532712 880054.92475
# INFO:tensorflow:Restoring parameters from ./sessions/32750.ckpt
# 633 32750 삼진 0.011819185 0.5070093 1291819.8429999999
# INFO:tensorflow:Restoring parameters from ./sessions/42940.ckpt
# 634 42940 상지카일룸 0.064521864 0.5257009 1221160.60175
# INFO:tensorflow:Restoring parameters from ./sessions/27040.ckpt
# 635 27040 서울전자통신 0.0439053 0.53504676 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/65710.ckpt
# 636 65710 서호전기 0.033689845 0.5268692 926916.31
# INFO:tensorflow:Restoring parameters from ./sessions/3100.ckpt
# 637 3100 선광 0.021392468 0.49415886 943321.6524999999
# INFO:tensorflow:Restoring parameters from ./sessions/45300.ckpt
# 638 45300 성우테크론 0.03621656 0.4906542 1091024.37925
# INFO:tensorflow:Restoring parameters from ./sessions/53060.ckpt
# 639 53060 세동 0.030223025 0.5186916 909443.8639999998
# INFO:tensorflow:Restoring parameters from ./sessions/52710.ckpt
# 640 52710 아모텍 0.037816953 0.48831776 981837.8274999999
# INFO:tensorflow:Restoring parameters from ./sessions/73070.ckpt
# 641 73070 에스모 0.018965483 0.5338785 1890390.73
# INFO:tensorflow:Restoring parameters from ./sessions/69510.ckpt
# 642 69510 에스텍 0.02812846 0.51635516 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/41910.ckpt
# 643 41910 에스텍파마 0.047041066 0.4614486 955427.8049999999
# INFO:tensorflow:Restoring parameters from ./sessions/52020.ckpt
# 644 52020 에스티큐브 0.026419047 0.50934577 1276323.8095
# INFO:tensorflow:Restoring parameters from ./sessions/58610.ckpt
# 645 58610 에스피지 0.031926505 0.5186916 1130916.192
# INFO:tensorflow:Restoring parameters from ./sessions/43580.ckpt
# 646 43580 에임하이 0.037144683 0.47196263 1004614.4605
# INFO:tensorflow:Restoring parameters from ./sessions/36810.ckpt
# 647 36810 에프에스티 0.03560587 0.47780374 953430.30625
# INFO:tensorflow:Restoring parameters from ./sessions/37950.ckpt
# 648 37950 엘컴텍 0.07999101 0.5619159 960409.4815
# INFO:tensorflow:Restoring parameters from ./sessions/9780.ckpt
# 649 9780 엠에스씨 0.06922844 0.48831776 883507.6599999999
# INFO:tensorflow:Restoring parameters from ./sessions/65500.ckpt
# 650 65500 오리엔트정공 0.068282135 0.48364487 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/67170.ckpt
# 651 67170 오텍 0.02647403 0.5151869 1184132.2375
# INFO:tensorflow:Restoring parameters from ./sessions/41190.ckpt
# 652 41190 우리기술투자 0.02529436 0.5268692 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/48430.ckpt
# 653 48430 유라테크 0.04451343 0.48364487 966664.31
# INFO:tensorflow:Restoring parameters from ./sessions/44960.ckpt
# 654 44960 이-글 벳 0.035928432 0.4661215 1076840.5742499998
# INFO:tensorflow:Restoring parameters from ./sessions/33230.ckpt
# 655 33230 인성정보 0.035713714 0.46728972 927863.04
# INFO:tensorflow:Restoring parameters from ./sessions/45510.ckpt
# 656 45510 정원엔시스 0.047201492 0.5420561 933950.9234999999
# INFO:tensorflow:Restoring parameters from ./sessions/34940.ckpt
# 657 34940 조아제약 0.015231028 0.4661215 899798.6925
# INFO:tensorflow:Restoring parameters from ./sessions/7370.ckpt
# 658 7370 진양제약 0.031052854 0.477396 942973.6014999998
# INFO:tensorflow:Restoring parameters from ./sessions/72520.ckpt
# 659 72520 케이디 네이쳐 엔 바이오 0.02249432 0.55607474 839933.1995
# INFO:tensorflow:Restoring parameters from ./sessions/73010.ckpt
# 660 73010 케이에스피 0.012507588 0.5911215 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/24880.ckpt
# 661 24880 케이피에프 0.022187652 0.52453274 951089.623
# INFO:tensorflow:Restoring parameters from ./sessions/27050.ckpt
# 662 27050 코리아나 0.046919804 0.47313085 931677.328
# INFO:tensorflow:Restoring parameters from ./sessions/65130.ckpt
# 663 65130 탑엔지니어링 0.028362028 0.47663552 1006980.4925
# INFO:tensorflow:Restoring parameters from ./sessions/53620.ckpt
# 664 53620 태양 0.03622371 0.52453274 1037536.8500000001
# INFO:tensorflow:Restoring parameters from ./sessions/54450.ckpt
# 665 54450 텔레칩스 0.013079435 0.51752335 940389.6699999999
# INFO:tensorflow:Restoring parameters from ./sessions/57880.ckpt
# 666 57880 토필드 0.051267065 0.482821 830262.74625
# INFO:tensorflow:Restoring parameters from ./sessions/66410.ckpt
# 667 66410 투윈글로벌 0.060275536 0.47377938 1213062.9125
# INFO:tensorflow:Restoring parameters from ./sessions/33540.ckpt
# 668 33540 파라텍 0.03327095 0.4754673 1016306.2780000003
# INFO:tensorflow:Restoring parameters from ./sessions/7330.ckpt
# 669 7330 푸른저축은행 0.03477099 0.4614486 1035782.407
# INFO:tensorflow:Restoring parameters from ./sessions/24660.ckpt
# 670 24660 하림홀딩스 0.040002823 0.4415888 944214.54375
# INFO:tensorflow:Restoring parameters from ./sessions/5860.ckpt
# 671 5860 한일사료 0.027243124 0.5 1069336.509
# INFO:tensorflow:Restoring parameters from ./sessions/54920.ckpt
# 672 54920 한컴시큐어 0.016117943 0.4906542 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/11080.ckpt
# 673 11080 형지I&C 0.04852076 0.5 957752.9404999999
# INFO:tensorflow:Restoring parameters from ./sessions/64240.ckpt
# 674 64240 홈캐스트 0.04080779 0.49532712 876517.12
# INFO:tensorflow:Restoring parameters from ./sessions/37440.ckpt
# 675 37440 희림 0.010504805 0.48714954 927416.2414999999
# INFO:tensorflow:Restoring parameters from ./sessions/5940.ckpt
# 676 5940 NH투자증권 0.021364262 0.5478972 1056487.9475000002
# INFO:tensorflow:Restoring parameters from ./sessions/64960.ckpt
# 677 64960 S&T모티브 0.025820542 0.49299064 977010.6974999999
# INFO:tensorflow:Restoring parameters from ./sessions/1740.ckpt
# 678 1740 SK네트웍스 0.0070769833 0.47780374 916418.056
# INFO:tensorflow:Restoring parameters from ./sessions/11420.ckpt
# 679 11420 갤럭시아에스엠 0.021225074 0.51635516 1238884.4640000002
# INFO:tensorflow:Restoring parameters from ./sessions/13580.ckpt
# 680 13580 계룡건설산업 0.011202314 0.5151869 984236.63
# INFO:tensorflow:Restoring parameters from ./sessions/10130.ckpt
# 681 10130 고려아연 0.025184207 0.4848131 1052196.15
# INFO:tensorflow:Restoring parameters from ./sessions/11780.ckpt
# 682 11780 금호석유화학 0.019448 0.45560747 940372.7549999999
# INFO:tensorflow:Restoring parameters from ./sessions/5720.ckpt
# 683 5720 넥센 0.052634403 0.5116823 1081210.2795000002
# INFO:tensorflow:Restoring parameters from ./sessions/5250.ckpt
# 684 5250 녹십자홀딩스 0.023731006 0.51752335 954461.5750000002
# INFO:tensorflow:Restoring parameters from ./sessions/4370.ckpt
# 685 4370 농심 0.037075106 0.47780374 978499.3
# INFO:tensorflow:Restoring parameters from ./sessions/4130.ckpt
# 686 4130 대덕GDS 0.026585449 0.51635516 1195391.94
# INFO:tensorflow:Restoring parameters from ./sessions/1680.ckpt
# 687 1680 대상 0.03146202 0.44976637 1048373.4825
# INFO:tensorflow:Restoring parameters from ./sessions/2880.ckpt
# 688 2880 대유에이텍 0.041793775 0.50116825 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/1070.ckpt
# 689 1070 대한방직 0.04815262 0.5490654 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/1790.ckpt
# 690 1790 대한제당 0.013162835 0.49649534 1040240.0475
# INFO:tensorflow:Restoring parameters from ./sessions/16090.ckpt
# 691 16090 대현 0.04668468 0.45911214 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/4830.ckpt
# 692 4830 덕성 0.0462994 0.52453274 998325.207
# INFO:tensorflow:Restoring parameters from ./sessions/23450.ckpt
# 693 23450 동남합성 0.026808325 0.45443925 982899.445
# INFO:tensorflow:Restoring parameters from ./sessions/5190.ckpt
# 694 5190 동성화학 0.036226884 0.45327103 1036914.765
# INFO:tensorflow:Restoring parameters from ./sessions/640.ckpt
# 695 640 동아쏘시오홀딩스 0.07641505 0.5070093 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/8970.ckpt
# 696 8970 동양철관 0.020999022 0.5140187 1122998.824
# INFO:tensorflow:Restoring parameters from ./sessions/3580.ckpt
# 697 3580 동원 0.06748116 0.48014018 1293508.995
# INFO:tensorflow:Restoring parameters from ./sessions/26890.ckpt
# 698 26890 디피씨 0.029186185 0.54088783 1034794.3254999999
# INFO:tensorflow:Restoring parameters from ./sessions/9200.ckpt
# 699 9200 무림페이퍼 0.011810191 0.5070093 1006556.55325
# INFO:tensorflow:Restoring parameters from ./sessions/1340.ckpt
# 700 1340 백광산업 0.010091165 0.51635516 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/35150.ckpt
# 701 35150 백산 0.030572781 0.48948598 1054213.7599999998
# INFO:tensorflow:Restoring parameters from ./sessions/11390.ckpt
# 702 11390 부산산업 0.038143776 0.48364487 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/3960.ckpt
# 703 3960 사조대림 0.028678505 0.5140187 1540068.445
# INFO:tensorflow:Restoring parameters from ./sessions/68290.ckpt
# 704 68290 삼성출판사 0.02225586 0.5035047 947815.47
# INFO:tensorflow:Restoring parameters from ./sessions/67830.ckpt
# 705 67830 세이브존I&C 0.0149397 0.52453274 1000505.079
# INFO:tensorflow:Restoring parameters from ./sessions/17550.ckpt
# 706 17550 수산중공업 0.036621824 0.49299064 977599.1379999999
# INFO:tensorflow:Restoring parameters from ./sessions/16590.ckpt
# 707 16590 신대양제지 0.029984701 0.52453274 1064445.5
# INFO:tensorflow:Restoring parameters from ./sessions/11930.ckpt
# 708 11930 신성이엔지 0.008515113 0.4906542 1105932.71
# INFO:tensorflow:Restoring parameters from ./sessions/9270.ckpt
# 709 9270 신원 0.004265995 0.5116823 1370798.97375
# INFO:tensorflow:Restoring parameters from ./sessions/5450.ckpt
# 710 5450 신한 0.010852324 0.51752335 810864.9700000001
# INFO:tensorflow:Restoring parameters from ./sessions/10600.ckpt
# 713 10600 웰바이오텍 0.0025209498 0.50934577 894181.0185
# INFO:tensorflow:Restoring parameters from ./sessions/8600.ckpt
# 714 8600 윌비스 0.023847532 0.4848131 870975.0695
# INFO:tensorflow:Restoring parameters from ./sessions/910.ckpt
# 715 910 유니온 0.0037587993 0.52453274 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/700.ckpt
# 716 700 유수홀딩스 0.011537711 0.50934577 1048116.3210000001
# INFO:tensorflow:Restoring parameters from ./sessions/14990.ckpt
# 717 14990 인디에프 0.009497041 0.47196263 841900.1174999995
# INFO:tensorflow:Restoring parameters from ./sessions/4910.ckpt
# 718 4910 조광페인트 0.036270816 0.49415886 927600.625
# INFO:tensorflow:Restoring parameters from ./sessions/10580.ckpt
# 719 10580 지코 0.027474934 0.5186916 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/7810.ckpt
# 720 7810 코리아써키트 0.035075102 0.49182242 1069558.7200000002
# INFO:tensorflow:Restoring parameters from ./sessions/5070.ckpt
# 721 5070 코스모신소재 0.032089338 0.50584114 1331175.23
# INFO:tensorflow:Restoring parameters from ./sessions/3240.ckpt
# 722 3240 태광산업 0.020456105 0.5081776 1163285.4500000002
# INFO:tensorflow:Restoring parameters from ./sessions/4100.ckpt
# 723 4100 태양금속공업 0.06997093 0.49883178 1316348.71925
# INFO:tensorflow:Restoring parameters from ./sessions/36580.ckpt
# 724 36580 팜스코 0.034987364 0.48831776 935829.79
# INFO:tensorflow:Restoring parameters from ./sessions/16800.ckpt
# 725 16800 퍼시스 0.038549367 0.47079438 976035.555
# INFO:tensorflow:Restoring parameters from ./sessions/1020.ckpt
# 726 1020 페이퍼코리아 0.007108119 0.49299064 973941.9543499999
# INFO:tensorflow:Restoring parameters from ./sessions/33180.ckpt
# 727 33180 필룩스 0.047994707 0.49532712 700662.7220000001
# INFO:tensorflow:Restoring parameters from ./sessions/140.ckpt
# 728 140 하이트진로홀딩스 0.0033026293 0.5140187 1016875.9575
# INFO:tensorflow:Restoring parameters from ./sessions/10040.ckpt
# 729 10040 한국내화 0.019900551 0.48948598 1009353.26275
# INFO:tensorflow:Restoring parameters from ./sessions/25540.ckpt
# 730 25540 한국단자공업 0.026519543 0.49415886 933964.4850000001
# INFO:tensorflow:Restoring parameters from ./sessions/14790.ckpt
# 731 14790 한라 0.0073671537 0.48714954 1031925.41
# INFO:tensorflow:Restoring parameters from ./sessions/25750.ckpt
# 732 25750 한솔홈데코 0.04202717 0.48948598 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/14130.ckpt
# 733 14130 한익스프레스 0.054652676 0.48598132 1079207.44
# INFO:tensorflow:Restoring parameters from ./sessions/3480.ckpt
# 734 3480 한진중공업홀딩스 0.004402116 0.53271025 1110348.2695
# INFO:tensorflow:Restoring parameters from ./sessions/27390.ckpt
# 735 27390 한화갤러리아타임월드 0.03932931 0.49766356 856491.4449999998
# INFO:tensorflow:Restoring parameters from ./sessions/9540.ckpt
# 736 9540 현대중공업 0.021550143 0.53154206 1007930.625
# INFO:tensorflow:Restoring parameters from ./sessions/60310.ckpt
# 737 60310 3S 0.011898953 0.4509346 1001171.8062500001
# INFO:tensorflow:Restoring parameters from ./sessions/23460.ckpt
# 738 23460 CNH 0.029747754 0.5338785 1090355.0395000002
# INFO:tensorflow:Restoring parameters from ./sessions/48770.ckpt
# 739 48770 TPC 0.0354349 0.49299064 906777.41
# INFO:tensorflow:Restoring parameters from ./sessions/51390.ckpt
# 740 51390 YW 0.013357538 0.510514 1026268.2412500001
# INFO:tensorflow:Restoring parameters from ./sessions/35460.ckpt
# 741 35460 기산텔레콤 0.016466899 0.4754673 920392.708
# INFO:tensorflow:Restoring parameters from ./sessions/7390.ckpt
# 742 7390 네이처셀 0.052971095 0.46728972 1097868.52
# INFO:tensorflow:Restoring parameters from ./sessions/32190.ckpt
# 743 32190 다우데이타 0.036886435 0.49649534 940431.01
# INFO:tensorflow:Restoring parameters from ./sessions/20400.ckpt
# 744 20400 대동금속 0.015689423 0.47663552 895257.6774999999
# INFO:tensorflow:Restoring parameters from ./sessions/8830.ckpt
# 745 8830 대동기어 0.023289008 0.48247662 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/6580.ckpt
# 746 6580 대양제지 0.032325584 0.54672897 1013085.4574999998
# INFO:tensorflow:Restoring parameters from ./sessions/10170.ckpt
# 747 10170 대한광통신 0.004925724 0.52803737 1097498.6867499999
# INFO:tensorflow:Restoring parameters from ./sessions/35290.ckpt
# 748 35290 더블유에프엠 0.04329135 0.53621495 979519.4607500001
# INFO:tensorflow:Restoring parameters from ./sessions/33500.ckpt
# 749 33500 동성화인텍 0.020575695 0.47780374 825128.5405000001
# INFO:tensorflow:Restoring parameters from ./sessions/41930.ckpt
# 750 41930 동아화성 0.022843502 0.46261683 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/60380.ckpt
# 751 60380 동양에스텍 0.022711284 0.5035047 1024476.58375
# INFO:tensorflow:Restoring parameters from ./sessions/73190.ckpt
# 752 73190 듀오백 0.029179223 0.51752335 887332.0085
# INFO:tensorflow:Restoring parameters from ./sessions/39840.ckpt
# 753 39840 디오 0.03242617 0.5070093 946690.66
# INFO:tensorflow:Restoring parameters from ./sessions/69540.ckpt
# 754 69540 라이트론 0.034289174 0.50233644 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/60300.ckpt
# 755 60300 레드로버 0.032445207 0.46378505 1126031.224
# INFO:tensorflow:Restoring parameters from ./sessions/65940.ckpt
# 756 65940 바이오빌 0.032033123 0.4567757 987199.9749999999
# INFO:tensorflow:Restoring parameters from ./sessions/14470.ckpt
# 757 14470 부방 0.027840212 0.5233645 994702.968
# INFO:tensorflow:Restoring parameters from ./sessions/54220.ckpt
# 758 54220 비츠로시스 0.01755198 0.48714954 953266.6175
# INFO:tensorflow:Restoring parameters from ./sessions/65570.ckpt
# 759 65570 삼영이엔씨 0.035658 0.49532712 956130.2949999998
# INFO:tensorflow:Restoring parameters from ./sessions/37460.ckpt
# 760 37460 삼지전자 0.043948095 0.52219623 905300.2285
# INFO:tensorflow:Restoring parameters from ./sessions/17510.ckpt
# 761 17510 세명전기 0.023265928 0.49182242 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/35610.ckpt
# 762 35610 솔본 0.03727384 0.47780374 956497.7599999999
# INFO:tensorflow:Restoring parameters from ./sessions/36830.ckpt
# 763 36830 솔브레인 0.028212 0.47780374 1169836.0
# INFO:tensorflow:Restoring parameters from ./sessions/49830.ckpt
# 764 49830 승일 0.050618373 0.52453274 948152.3825000001
# INFO:tensorflow:Restoring parameters from ./sessions/41440.ckpt
# 765 41440 에버다임 0.04319197 0.48714954 1024588.4425
# INFO:tensorflow:Restoring parameters from ./sessions/38680.ckpt
# 766 38680 에스넷 0.048103712 0.48714954 935079.1865000001
# INFO:tensorflow:Restoring parameters from ./sessions/14940.ckpt
# 767 14940 오리엔탈정공 0.014525414 0.51752335 923804.626
# INFO:tensorflow:Restoring parameters from ./sessions/31510.ckpt
# 768 31510 오스템 0.033572163 0.48598132 973579.3125
# INFO:tensorflow:Restoring parameters from ./sessions/32820.ckpt
# 769 32820 우리기술 0.016165458 0.557243 873153.2912000002
# INFO:tensorflow:Restoring parameters from ./sessions/72470.ckpt
# 770 72470 우리산업홀딩스 0.046456814 0.49766356 995885.9915
# INFO:tensorflow:Restoring parameters from ./sessions/74600.ckpt
# 771 74600 원익QnC 0.04286356 0.47313085 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/8290.ckpt
# 772 8290 원풍물산 0.03225744 0.48831776 933272.703
# INFO:tensorflow:Restoring parameters from ./sessions/26260.ckpt
# 773 26260 위너지스 0.046614416 0.4754673 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/41520.ckpt
# 774 41520 이라이콤 0.031494875 0.4567757 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/19570.ckpt
# 775 19570 제미니투자 0.04604742 0.5140187 953079.0133000001
# INFO:tensorflow:Restoring parameters from ./sessions/52670.ckpt
# 776 52670 제일바이오 0.044958197 0.46378505 950117.6095
# INFO:tensorflow:Restoring parameters from ./sessions/54180.ckpt
# 777 54180 중앙오션 0.009337872 0.47429907 1896871.9734999998
# INFO:tensorflow:Restoring parameters from ./sessions/18120.ckpt
# 778 18120 진로발효 0.03005979 0.50994575 1025656.685
# INFO:tensorflow:Restoring parameters from ./sessions/16920.ckpt
# 779 16920 카스 0.04706001 0.53154206 1067651.5180000002
# INFO:tensorflow:Restoring parameters from ./sessions/16170.ckpt
# 780 16170 카카오M 0.034501947 0.51635516 984909.8150000001
# INFO:tensorflow:Restoring parameters from ./sessions/39420.ckpt
# 781 39420 케이엘넷 0.011185813 0.48598132 927846.08
# INFO:tensorflow:Restoring parameters from ./sessions/52400.ckpt
# 782 52400 코나아이 0.03856436 0.4813084 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/56360.ckpt
# 783 56360 코위버 0.02690123 0.5046729 1000498.22
# INFO:tensorflow:Restoring parameters from ./sessions/51780.ckpt
# 784 51780 큐로홀딩스 0.04135361 0.48364487 968807.7374999999
# INFO:tensorflow:Restoring parameters from ./sessions/37070.ckpt
# 785 37070 파세코 0.043535195 0.49299064 1106127.175
# INFO:tensorflow:Restoring parameters from ./sessions/5670.ckpt
# 786 5670 푸드웰 0.011962326 0.51285046 913432.3215
# INFO:tensorflow:Restoring parameters from ./sessions/23770.ckpt
# 787 23770 플레이위드 0.05028451 0.5027125 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/39340.ckpt
# 788 39340 한국경제TV 0.010360488 0.49182242 993532.9217499999
# INFO:tensorflow:Restoring parameters from ./sessions/25550.ckpt
# 789 25550 한국선재 0.021041825 0.52453274 990413.272
# INFO:tensorflow:Restoring parameters from ./sessions/17890.ckpt
# 790 17890 한국알콜 0.007902641 0.48831776 953858.5765
# INFO:tensorflow:Restoring parameters from ./sessions/54040.ckpt
# 791 54040 한국컴퓨터 0.030126426 0.5338785 1036952.1664999997
# INFO:tensorflow:Restoring parameters from ./sessions/52600.ckpt
# 792 52600 한네트 0.057264384 0.48014018 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/2680.ckpt
# 793 2680 한탑 0.018699126 0.47196263 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/78930.ckpt
# 794 78930 GS 0.018242015 0.5081776 1139821.52
# INFO:tensorflow:Restoring parameters from ./sessions/8260.ckpt
# 795 8260 NI스틸 0.03137534 0.48598132 904547.2250000001
# INFO:tensorflow:Restoring parameters from ./sessions/10060.ckpt
# 796 10060 OCI 0.0095303655 0.5186916 1065162.94
# INFO:tensorflow:Restoring parameters from ./sessions/11790.ckpt
# 797 11790 SKC 0.019064384 0.4813084 1170726.75
# INFO:tensorflow:Restoring parameters from ./sessions/11810.ckpt
# 798 11810 STX 0.019704 0.5198598 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/35250.ckpt
# 799 35250 강원랜드 0.029483879 0.46495327 967673.095
# INFO:tensorflow:Restoring parameters from ./sessions/12610.ckpt
# 800 12610 경인양행 0.010106239 0.46495327 982285.65775
# INFO:tensorflow:Restoring parameters from ./sessions/4200.ckpt
# 801 4200 고려개발 0.03513512 0.5233645 1151319.5535
# INFO:tensorflow:Restoring parameters from ./sessions/37710.ckpt
# 802 37710 광주신세계 0.02353523 0.52102804 972037.3
# INFO:tensorflow:Restoring parameters from ./sessions/2720.ckpt
# 803 2720 국제약품 0.020111348 0.46728972 920992.41525
# INFO:tensorflow:Restoring parameters from ./sessions/4270.ckpt
# 804 4270 남성 0.06912304 0.5233645 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/2350.ckpt
# 805 2350 넥센타이어 0.00936072 0.4848131 950720.0225
# INFO:tensorflow:Restoring parameters from ./sessions/8060.ckpt
# 806 8060 대덕전자 0.021385295 0.48714954 1163606.2625000002
# INFO:tensorflow:Restoring parameters from ./sessions/8110.ckpt
# 807 8110 대동전자 0.03161816 0.5 1011121.3850000001
# INFO:tensorflow:Restoring parameters from ./sessions/9320.ckpt
# 808 9320 대우부품 0.0008547069 0.51635516 1026144.8919999999
# INFO:tensorflow:Restoring parameters from ./sessions/69620.ckpt
# 809 69620 대웅제약 0.03184929 0.44976637 888981.1049999999
# INFO:tensorflow:Restoring parameters from ./sessions/6340.ckpt
# 810 6340 대원전선 0.0050507127 0.4813084 1084362.083
# INFO:tensorflow:Restoring parameters from ./sessions/6650.ckpt
# 811 6650 대한유화 0.03924234 0.48948598 1044739.3
# INFO:tensorflow:Restoring parameters from ./sessions/1230.ckpt
# 812 1230 동국제강 0.07297691 0.49182242 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/7590.ckpt
# 813 7590 동방아그로 0.03791712 0.510514 976886.311
# INFO:tensorflow:Restoring parameters from ./sessions/30720.ckpt
# 814 30720 동원수산 0.025730474 0.49883178 1121253.4
# INFO:tensorflow:Restoring parameters from ./sessions/14820.ckpt
# 815 14820 동원시스템즈 0.025955006 0.5151869 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/20.ckpt
# 816 20 동화약품 0.004004852 0.5140187 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/1080.ckpt
# 817 1080 만호제강 0.0063357325 0.49649534 984791.2500000001
# INFO:tensorflow:Restoring parameters from ./sessions/7210.ckpt
# 818 7210 벽산 0.022693677 0.49415886 917377.807
# INFO:tensorflow:Restoring parameters from ./sessions/6090.ckpt
# 819 6090 사조오양 0.016172206 0.4602804 1227544.72
# INFO:tensorflow:Restoring parameters from ./sessions/5090.ckpt
# 820 5090 삼광글라스 0.03163377 0.52803737 935923.0499999998
# INFO:tensorflow:Restoring parameters from ./sessions/6400.ckpt
# 821 6400 삼성SDI 0.035304572 0.5046729 1138393.0
# INFO:tensorflow:Restoring parameters from ./sessions/5680.ckpt
# 822 5680 삼영전자공업 0.036127437 0.53621495 1036348.33
# INFO:tensorflow:Restoring parameters from ./sessions/3720.ckpt
# 823 3720 삼영화학공업 0.011575817 0.51285046 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/5500.ckpt
# 824 5500 삼진제약 0.010737594 0.49182242 912457.1099999996
# INFO:tensorflow:Restoring parameters from ./sessions/9470.ckpt
# 825 9470 삼화전기 0.02655649 0.50116825 1204812.85
# INFO:tensorflow:Restoring parameters from ./sessions/7860.ckpt
# 826 7860 서연 0.043278936 0.55140185 980847.8125
# INFO:tensorflow:Restoring parameters from ./sessions/7610.ckpt
# 827 7610 선도전기 0.033900168 0.510514 954824.65975
# INFO:tensorflow:Restoring parameters from ./sessions/11300.ckpt
# 828 11300 성안 0.010649584 0.53504676 822816.1436000001
# INFO:tensorflow:Restoring parameters from ./sessions/4490.ckpt
# 829 4490 세방전지 0.021237241 0.48247662 998595.2849999999
# INFO:tensorflow:Restoring parameters from ./sessions/5390.ckpt
# 830 5390 신성통상 0.014114782 0.48831776 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/19170.ckpt
# 831 19170 신풍제약 0.011327076 0.49766356 899400.8585
# INFO:tensorflow:Restoring parameters from ./sessions/3410.ckpt
# 832 3410 쌍용양회공업 0.029856985 0.5070093 998525.7124999999
# INFO:tensorflow:Restoring parameters from ./sessions/4920.ckpt
# 833 4920 씨아이테크 0.003114317 0.47897196 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/9810.ckpt
# 834 9810 엔케이물산 0.04172092 0.510514 915426.6619000001
# INFO:tensorflow:Restoring parameters from ./sessions/1800.ckpt
# 835 1800 오리온홀딩스 0.03117363 0.4813084 1058213.6
# INFO:tensorflow:Restoring parameters from ./sessions/10050.ckpt
# 836 10050 우리종금 0.02316823 0.47897196 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/5820.ckpt
# 837 5820 원림 0.033103798 0.5070093 1023293.5349999999
# INFO:tensorflow:Restoring parameters from ./sessions/77500.ckpt
# 838 77500 유니퀘스트 0.04342525 0.50584114 975485.1625000001
# INFO:tensorflow:Restoring parameters from ./sessions/23810.ckpt
# 839 23810 인팩 0.03938474 0.5292056 1055816.089
# INFO:tensorflow:Restoring parameters from ./sessions/13360.ckpt
# 840 13360 일성건설 0.03273174 0.49415886 931287.4000000001
# INFO:tensorflow:Restoring parameters from ./sessions/3120.ckpt
# 841 3120 일성신약 0.031570464 0.5478972 1018135.6
# INFO:tensorflow:Restoring parameters from ./sessions/2620.ckpt
# 842 2620 제일파마홀딩스 0.034248013 0.5829439 982661.83
# INFO:tensorflow:Restoring parameters from ./sessions/1630.ckpt
# 843 1630 종근당홀딩스 0.0378488 0.50233644 989493.3699999999
# INFO:tensorflow:Restoring parameters from ./sessions/10640.ckpt
# 844 10640 진양폴리우레탄 0.022258753 0.7196262 905513.5337500001
# INFO:tensorflow:Restoring parameters from ./sessions/30200.ckpt
# 845 30200 케이티 0.026372354 0.5140187 1001315.7974999999
# INFO:tensorflow:Restoring parameters from ./sessions/3690.ckpt
# 846 3690 코리안리 0.029033689 0.5186916 972222.4525000001
# INFO:tensorflow:Restoring parameters from ./sessions/3070.ckpt
# 847 3070 코오롱글로벌 0.048741248 0.5490654 879795.355
# INFO:tensorflow:Restoring parameters from ./sessions/71090.ckpt
# 848 71090 하이스틸 0.021776164 0.5081776 970128.795
# INFO:tensorflow:Restoring parameters from ./sessions/36460.ckpt
# 849 36460 한국가스공사 0.039304495 0.48014018 1127126.725
# INFO:tensorflow:Restoring parameters from ./sessions/3350.ckpt
# 850 3350 한국화장품제조 0.059110932 0.510514 944131.8300000001
# INFO:tensorflow:Restoring parameters from ./sessions/2390.ckpt
# 851 2390 한독 0.0481615 0.5035047 1032504.2999999999
# INFO:tensorflow:Restoring parameters from ./sessions/3680.ckpt
# 852 3680 한성기업 0.02991139 0.49415886 955569.1135
# INFO:tensorflow:Restoring parameters from ./sessions/10420.ckpt
# 853 10420 한솔피엔에스 0.0034744476 0.52453274 982164.152
# INFO:tensorflow:Restoring parameters from ./sessions/11700.ckpt
# 854 11700 한신기계공업 0.0066787763 0.4906542 1332974.0037500001
# INFO:tensorflow:Restoring parameters from ./sessions/9420.ckpt
# 855 9420 한올바이오파마 0.03250074 0.5081776 892010.3249999998
# INFO:tensorflow:Restoring parameters from ./sessions/9830.ckpt
# 856 9830 한화케미칼 0.01970974 0.49299064 1219826.23
# INFO:tensorflow:Restoring parameters from ./sessions/11200.ckpt
# 857 11200 현대상선 0.02219424 0.53271025 1029351.9439999999
# INFO:tensorflow:Restoring parameters from ./sessions/850.ckpt
# 858 850 화천기공 0.024369426 0.48364487 1081844.4
# INFO:tensorflow:Restoring parameters from ./sessions/32040.ckpt
# 859 32040 C&S자산관리 0.05261238 0.50584114 971778.9629999999
# INFO:tensorflow:Restoring parameters from ./sessions/65770.ckpt
# 860 65770 CS 0.014432031 0.5116823 956616.3359999999
# INFO:tensorflow:Restoring parameters from ./sessions/28150.ckpt
# 861 28150 GS홈쇼핑 0.028129846 0.48714954 989621.88
# INFO:tensorflow:Restoring parameters from ./sessions/36030.ckpt
# 862 36030 KTH 0.042303957 0.4661215 965065.373
# INFO:tensorflow:Restoring parameters from ./sessions/60250.ckpt
# 863 60250 NHN한국사이버결제 0.04137251 0.47196263 991218.8975
# INFO:tensorflow:Restoring parameters from ./sessions/63440.ckpt
# 864 63440 SM Life Design 0.020513788 0.5303738 1169222.841
# INFO:tensorflow:Restoring parameters from ./sessions/24840.ckpt
# 865 24840 갑을메탈 0.06660146 0.5186916 1124131.0262499999
# INFO:tensorflow:Restoring parameters from ./sessions/24910.ckpt
# 866 24910 경창산업 0.02606139 0.5035047 976564.0790000001
# INFO:tensorflow:Restoring parameters from ./sessions/19660.ckpt
# 867 19660 글로본 0.033236958 0.5035047 837427.5195
# INFO:tensorflow:Restoring parameters from ./sessions/36190.ckpt
# 868 36190 금화피에스시 0.03530358 0.5525701 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/36800.ckpt
# 869 36800 나이스정보통신 0.02395251 0.50584114 963449.6749999999
# INFO:tensorflow:Restoring parameters from ./sessions/45390.ckpt
# 870 45390 대아티아이 0.019098556 0.46261683 981957.84075
# INFO:tensorflow:Restoring parameters from ./sessions/48910.ckpt
# 871 48910 대원미디어 0.027109487 0.4906542 875599.4079999999
# INFO:tensorflow:Restoring parameters from ./sessions/54670.ckpt
# 872 54670 대한뉴팜 0.04737956 0.46378505 953339.6799999999
# INFO:tensorflow:Restoring parameters from ./sessions/67990.ckpt
# 873 67990 도이치모터스 0.031649474 0.48831776 1137525.436
# INFO:tensorflow:Restoring parameters from ./sessions/25900.ckpt
# 874 25900 동화기업 0.055162568 0.47429907 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/66670.ckpt
# 875 66670 디스플레이텍 0.034442425 0.48598132 1135667.202
# INFO:tensorflow:Restoring parameters from ./sessions/42510.ckpt
# 876 42510 라온시큐어 0.03660508 0.49299064 991596.2799999999
# INFO:tensorflow:Restoring parameters from ./sessions/39980.ckpt
# 877 39980 리노스 0.015727505 0.44859812 891837.5455
# INFO:tensorflow:Restoring parameters from ./sessions/38290.ckpt
# 878 38290 마크로젠 0.042483572 0.46495327 890093.6225
# INFO:tensorflow:Restoring parameters from ./sessions/65650.ckpt
# 879 65650 메디프론 0.032769643 0.47780374 1082240.3649999998
# INFO:tensorflow:Restoring parameters from ./sessions/28040.ckpt
# 880 28040 미래SCI 0.040178973 0.50934577 929898.18775
# INFO:tensorflow:Restoring parameters from ./sessions/64520.ckpt
# 881 64520 바른전자 0.0345379 0.47196263 969204.2735
# INFO:tensorflow:Restoring parameters from ./sessions/38460.ckpt
# 882 38460 바이오스마트 0.04228324 0.47780374 1076492.78525
# INFO:tensorflow:Restoring parameters from ./sessions/14970.ckpt
# 883 14970 삼륭물산 0.0112001635 0.4661215 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/46890.ckpt
# 884 46890 서울반도체 0.020427017 0.4848131 1100773.2699999998
# INFO:tensorflow:Restoring parameters from ./sessions/20710.ckpt
# 885 20710 시공테크 0.033432625 0.5373832 983415.2520000001
# INFO:tensorflow:Restoring parameters from ./sessions/25870.ckpt
# 886 25870 신라에스지 0.051098824 0.47429907 929726.4600000002
# INFO:tensorflow:Restoring parameters from ./sessions/12790.ckpt
# 887 12790 신일제약 0.03965339 0.50584114 925915.2875000001
# INFO:tensorflow:Restoring parameters from ./sessions/25980.ckpt
# 888 25980 아난티 0.0484474 0.48598132 1053943.2850000001
# INFO:tensorflow:Restoring parameters from ./sessions/60570.ckpt
# 889 60570 아이리버 0.03310229 0.48714954 875642.578
# INFO:tensorflow:Restoring parameters from ./sessions/38880.ckpt
# 890 38880 아이에이 0.01941376 0.56658876 923905.146
# INFO:tensorflow:Restoring parameters from ./sessions/50760.ckpt
# 891 50760 에스폴리텍 0.020307105 0.5116823 1023133.657
# INFO:tensorflow:Restoring parameters from ./sessions/54630.ckpt
# 892 54630 에이디칩스 0.009751584 0.48714954 880180.9430000002
# INFO:tensorflow:Restoring parameters from ./sessions/43220.ckpt
# 893 43220 에이치엘비파워 0.08968755 0.567757 934613.0739999999
# INFO:tensorflow:Restoring parameters from ./sessions/21080.ckpt
# 894 21080 에이티넘인베스트 0.04807973 0.49532712 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/73570.ckpt
# 895 73570 에이티테크놀러지 0.04170254 0.51635516 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/65950.ckpt
# 896 65950 웰크론 0.029096117 0.47196263 970526.1944999999
# INFO:tensorflow:Restoring parameters from ./sessions/36200.ckpt
# 897 36200 유니셈 0.049582586 0.49415886 1072106.0350000001
# INFO:tensorflow:Restoring parameters from ./sessions/49520.ckpt
# 898 49520 유아이엘 0.019437982 0.53271025 1139245.1575000002
# INFO:tensorflow:Restoring parameters from ./sessions/56080.ckpt
# 899 56080 유진로봇 0.028507087 0.4754673 975384.0235
# INFO:tensorflow:Restoring parameters from ./sessions/60230.ckpt
# 900 60230 이그잭스 0.026823357 0.48598132 876297.8647500001
# INFO:tensorflow:Restoring parameters from ./sessions/54210.ckpt
# 901 54210 이랜텍 0.04356015 0.5140187 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/65440.ckpt
# 902 65440 이루온 0.038466293 0.47196263 965603.9500000001
# INFO:tensorflow:Restoring parameters from ./sessions/24810.ckpt
# 903 24810 이화전기 0.0077415644 0.59345794 731851.3501499998
# INFO:tensorflow:Restoring parameters from ./sessions/37330.ckpt
# 904 37330 인지디스플레 0.019027844 0.48598132 943469.995
# INFO:tensorflow:Restoring parameters from ./sessions/17250.ckpt
# 905 17250 인터엠 0.03833869 0.5046729 1005405.072
# INFO:tensorflow:Restoring parameters from ./sessions/35080.ckpt
# 906 35080 인터파크홀딩스 0.039818496 0.4602804 1075600.7404999998
# INFO:tensorflow:Restoring parameters from ./sessions/49550.ckpt
# 907 49550 잉크테크 0.014356755 0.5334539 937430.5599999999
# INFO:tensorflow:Restoring parameters from ./sessions/40420.ckpt
# 908 40420 정상제이엘에스 0.015359311 0.5443925 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/33100.ckpt
# 909 33100 제룡전기 0.03696369 0.5070093 1181689.7425000002
# INFO:tensorflow:Restoring parameters from ./sessions/58420.ckpt
# 910 58420 제이웨이 0.05325498 0.55607474 909541.097
# INFO:tensorflow:Restoring parameters from ./sessions/23440.ckpt
# 911 23440 제일제강 0.07684094 0.60397196 932613.64525
# INFO:tensorflow:Restoring parameters from ./sessions/33340.ckpt
# 912 33340 좋은사람들 0.03342713 0.510514 969159.3319999999
# INFO:tensorflow:Restoring parameters from ./sessions/42040.ckpt
# 913 42040 케이피엠테크 0.034297436 0.5864486 1032507.4799999999
# INFO:tensorflow:Restoring parameters from ./sessions/46070.ckpt
# 914 46070 코다코 0.02039001 0.49299064 940247.3357500001
# INFO:tensorflow:Restoring parameters from ./sessions/47770.ckpt
# 915 47770 코데즈컴바인 0.05896245 0.62383175 823501.139
# INFO:tensorflow:Restoring parameters from ./sessions/45970.ckpt
# 916 45970 코아시아홀딩스 0.016918795 0.49649534 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/52330.ckpt
# 917 52330 코텍 0.03456269 0.48714954 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/40350.ckpt
# 918 40350 큐로컴 0.02672961 0.4848131 1013661.3265
# INFO:tensorflow:Restoring parameters from ./sessions/54780.ckpt
# 919 54780 키이스트 0.0074805436 0.49415886 920013.9152500001
# INFO:tensorflow:Restoring parameters from ./sessions/43090.ckpt
# 920 43090 팜스웰바이오 0.02885367 0.48598132 845264.5817499999
# INFO:tensorflow:Restoring parameters from ./sessions/9520.ckpt
# 921 9520 포스코엠텍 0.017386789 0.5035047 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/35200.ckpt
# 922 35200 프럼파스트 0.029187072 0.47429907 1084096.7205000003
# INFO:tensorflow:Restoring parameters from ./sessions/23760.ckpt
# 923 23760 한국캐피탈 0.0016770638 0.51285046 1015125.1587
# INFO:tensorflow:Restoring parameters from ./sessions/21650.ckpt
# 924 21650 한국큐빅 0.033410717 0.49532712 957789.3812500001
# INFO:tensorflow:Restoring parameters from ./sessions/37230.ckpt
# 925 37230 한국팩키지 0.013010607 0.5046729 931182.0152499999
# INFO:tensorflow:Restoring parameters from ./sessions/47080.ckpt
# 926 47080 한빛소프트 0.040256914 0.50584114 966726.3595
# INFO:tensorflow:Restoring parameters from ./sessions/70590.ckpt
# 927 70590 한솔인티큐브 0.031177403 0.47897196 911444.5074999997
# INFO:tensorflow:Restoring parameters from ./sessions/8800.ckpt
# 928 8800 행남사 0.071167156 0.5 1113624.0304000005
# INFO:tensorflow:Restoring parameters from ./sessions/28080.ckpt
# 929 28080 휴맥스홀딩스 0.009534505 0.54672897 972440.7999999999
# INFO:tensorflow:Restoring parameters from ./sessions/65510.ckpt
# 930 65510 휴비츠 0.039858505 0.48364487 983825.2074999999
# INFO:tensorflow:Restoring parameters from ./sessions/11150.ckpt
# 931 11150 CJ씨푸드 0.03584237 0.49182242 988779.704
# INFO:tensorflow:Restoring parameters from ./sessions/7700.ckpt
# 932 7700 F&F 0.030893266 0.53271025 1018051.5700000001
# INFO:tensorflow:Restoring parameters from ./sessions/1390.ckpt
# 933 1390 KG케미칼 0.03194472 0.5338785 999280.2525
# INFO:tensorflow:Restoring parameters from ./sessions/51910.ckpt
# 934 51910 LG화학 0.023662977 0.48714954 1005923.3499999997
# INFO:tensorflow:Restoring parameters from ./sessions/6260.ckpt
# 935 6260 LS 0.01658286 0.48364487 1100888.06
# INFO:tensorflow:Restoring parameters from ./sessions/3570.ckpt
# 936 3570 S&T중공업 0.019511016 0.52453274 1062101.8915
# INFO:tensorflow:Restoring parameters from ./sessions/1380.ckpt
# 937 1380 SG충방 0.023005897 0.49182242 932524.5262499998
# INFO:tensorflow:Restoring parameters from ./sessions/77970.ckpt
# 938 77970 STX엔진 0.06410916 0.614486 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/500.ckpt
# 939 500 가온전선 0.018705972 0.5257009 1082503.54
# INFO:tensorflow:Restoring parameters from ./sessions/860.ckpt
# 940 860 강남제비스코 0.03242532 0.52219623 1007765.5499999999
# INFO:tensorflow:Restoring parameters from ./sessions/9450.ckpt
# 941 9450 경동나비엔 0.03321319 0.5 1039746.8299999998
# INFO:tensorflow:Restoring parameters from ./sessions/17900.ckpt
# 942 17900 광전자 0.017631212 0.49883178 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/14530.ckpt
# 943 14530 극동유화 0.06289495 0.56542057 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/74610.ckpt
# 944 74610 나노메딕스 0.029045407 0.47780374 1726069.0125000002
# INFO:tensorflow:Restoring parameters from ./sessions/8350.ckpt
# 945 8350 남선알미늄 0.0054511996 0.5046729 1087713.55375
# INFO:tensorflow:Restoring parameters from ./sessions/490.ckpt
# 946 490 대동공업 0.01899208 0.51635516 1227516.1
# INFO:tensorflow:Restoring parameters from ./sessions/5750.ckpt
# 947 5750 대림비앤코 0.045234825 0.48831776 939952.0249999999
# INFO:tensorflow:Restoring parameters from ./sessions/300.ckpt
# 948 300 대유플러스 0.007666658 0.5116823 1028164.74775
# INFO:tensorflow:Restoring parameters from ./sessions/1520.ckpt
# 949 1520 동양 0.010636557 0.5490654 945935.6257500001
# INFO:tensorflow:Restoring parameters from ./sessions/49770.ckpt
# 950 49770 동원F&B 0.034188066 0.5140187 923063.5
# INFO:tensorflow:Restoring parameters from ./sessions/7340.ckpt
# 951 7340 디티알오토모티브 0.027646326 0.4614486 983662.465
# INFO:tensorflow:Restoring parameters from ./sessions/12690.ckpt
# 952 12690 모나리자 0.042080708 0.49415886 904907.8225000001
# INFO:tensorflow:Restoring parameters from ./sessions/5360.ckpt
# 953 5360 모나미 0.014255751 0.49532712 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/6800.ckpt
# 954 6800 미래에셋대우 0.01653986 0.53971964 1264748.656
# INFO:tensorflow:Restoring parameters from ./sessions/3650.ckpt
# 955 3650 미창석유공업 0.025103778 0.49415886 1005906.23
# INFO:tensorflow:Restoring parameters from ./sessions/2410.ckpt
# 956 2410 범양건영 0.078073375 0.6179907 1050471.7175000003
# INFO:tensorflow:Restoring parameters from ./sessions/3000.ckpt
# 957 3000 부광약품 0.045657955 0.49532712 877953.6474999998
# INFO:tensorflow:Restoring parameters from ./sessions/16360.ckpt
# 958 16360 삼성증권 0.018021824 0.50584114 1206918.6974999998
# INFO:tensorflow:Restoring parameters from ./sessions/810.ckpt
# 959 810 삼성화재해상보험 0.029690921 0.46495327 1043475.7000000001
# INFO:tensorflow:Restoring parameters from ./sessions/1880.ckpt
# 960 1880 삼호 0.027434735 0.50233644 1302177.5499999998
# INFO:tensorflow:Restoring parameters from ./sessions/4450.ckpt
# 961 4450 삼화왕관 0.028440112 0.53504676 1162227.065
# INFO:tensorflow:Restoring parameters from ./sessions/3080.ckpt
# 962 3080 성보화학 0.09880487 0.55140185 1087211.254
# INFO:tensorflow:Restoring parameters from ./sessions/13000.ckpt
# 963 13000 세우글로벌 0.037232324 0.48831776 954282.43225
# INFO:tensorflow:Restoring parameters from ./sessions/29530.ckpt
# 964 29530 신도리코 0.03085597 0.49182242 1062915.22
# INFO:tensorflow:Restoring parameters from ./sessions/4970.ckpt
# 965 4970 신라교역 0.04256407 0.53154206 927882.6625
# INFO:tensorflow:Restoring parameters from ./sessions/55550.ckpt
# 966 55550 신한지주 0.02441688 0.45911214 1025752.35
# INFO:tensorflow:Restoring parameters from ./sessions/4770.ckpt
# 967 4770 써니전자 0.011113159 0.49415886 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/2250.ckpt
# 968 2250 알보젠코리아 0.036896024 0.5140187 976179.515
# INFO:tensorflow:Restoring parameters from ./sessions/3060.ckpt
# 969 3060 에이프로젠제약 0.06796404 0.5151869 930828.5144999999
# INFO:tensorflow:Restoring parameters from ./sessions/6980.ckpt
# 970 6980 우성사료 0.010157475 0.47897196 896751.4569999999
# INFO:tensorflow:Restoring parameters from ./sessions/7110.ckpt
# 971 7110 일신석재 0.004092069 0.49182242 1044076.0485
# INFO:tensorflow:Restoring parameters from ./sessions/6220.ckpt
# 972 6220 제주은행 0.054580808 0.50233644 1030113.2239999999
# INFO:tensorflow:Restoring parameters from ./sessions/9310.ckpt
# 973 9310 참엔지니어링 0.033716477 0.71378505 930669.9665
# INFO:tensorflow:Restoring parameters from ./sessions/12600.ckpt
# 974 12600 청호컴넷 0.008003735 0.50934577 934649.552
# INFO:tensorflow:Restoring parameters from ./sessions/6380.ckpt
# 975 6380 카프로 0.009038829 0.5046729 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/11280.ckpt
# 976 11280 태림포장 0.016575532 0.49766356 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/78000.ckpt
# 977 78000 텔코웨어 0.020386139 0.56542057 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/19180.ckpt
# 978 19180 티에이치엔 0.029877158 0.50584114 942850.25425
# INFO:tensorflow:Restoring parameters from ./sessions/15760.ckpt
# 979 15760 한국전력공사 0.03279878 0.49532712 965547.2300000002
# INFO:tensorflow:Restoring parameters from ./sessions/2300.ckpt
# 980 2300 한국제지 0.028517976 0.54672897 956982.2450000001
# INFO:tensorflow:Restoring parameters from ./sessions/8930.ckpt
# 981 8930 한미사이언스 0.04067609 0.51752335 1356063.44
# INFO:tensorflow:Restoring parameters from ./sessions/4150.ckpt
# 982 4150 한솔홀딩스 0.023595495 0.54672897 1012636.2444999999
# INFO:tensorflow:Restoring parameters from ./sessions/12450.ckpt
# 983 12450 한화에어로스페이스 0.023958078 0.51285046 966521.1449999999
# INFO:tensorflow:Restoring parameters from ./sessions/3530.ckpt
# 984 3530 한화투자증권 0.00745989 0.5432243 1583797.2895
# INFO:tensorflow:Restoring parameters from ./sessions/4020.ckpt
# 985 4020 현대제철 0.01681947 0.4848131 1166712.745
# INFO:tensorflow:Restoring parameters from ./sessions/11760.ckpt
# 986 11760 현대종합상사 0.08823345 0.49532712 966082.24
# INFO:tensorflow:Restoring parameters from ./sessions/1450.ckpt
# 987 1450 현대해상 0.02582545 0.48247662 1053017.4449999998
# INFO:tensorflow:Restoring parameters from ./sessions/2460.ckpt
# 988 2460 화성산업 0.047750007 0.53154206 1094268.6624999999
# INFO:tensorflow:Restoring parameters from ./sessions/13520.ckpt
# 989 13520 화승알앤에이 0.039132576 0.48831776 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/35760.ckpt
# 990 35760 CJ오쇼핑 0.043865725 0.48948598 964984.35
# INFO:tensorflow:Restoring parameters from ./sessions/78150.ckpt
# 991 78150 HB테크놀러지 0.030494403 0.49299064 841635.293
# INFO:tensorflow:Restoring parameters from ./sessions/67290.ckpt
# 992 67290 JW신약 0.016420215 0.4602804 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/21320.ckpt
# 993 21320 KCC건설 0.082590856 0.5070093 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/60720.ckpt
# 994 60720 KH바텍 0.030385455 0.50934577 941777.1599999999
# INFO:tensorflow:Restoring parameters from ./sessions/24940.ckpt
# 995 24940 PN풍년 0.012131412 0.5186916 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/46140.ckpt
# 996 46140 SBS콘텐츠허브 0.035503954 0.53154206 1060929.3684999999
# INFO:tensorflow:Restoring parameters from ./sessions/38340.ckpt
# 997 38340 UCI 0.05591062 0.5724299 994714.8400000001
# INFO:tensorflow:Restoring parameters from ./sessions/53950.ckpt
# 998 53950 경남제약 0.0625477 0.50233644 1614944.5325
# INFO:tensorflow:Restoring parameters from ./sessions/49720.ckpt
# 999 49720 고려신용정보 0.040466428 0.50584114 966056.8
# INFO:tensorflow:Restoring parameters from ./sessions/66620.ckpt
# 1000 66620 국보디자인 0.04168409 0.5151869 1152284.77
# INFO:tensorflow:Restoring parameters from ./sessions/65170.ckpt
# 1001 65170 넥스트BT 0.012591769 0.49415886 985054.7249999999
# INFO:tensorflow:Restoring parameters from ./sessions/65560.ckpt
# 1002 65560 녹원씨엔아이 0.042926513 0.5198598 883451.563
# INFO:tensorflow:Restoring parameters from ./sessions/5710.ckpt
# 1003 5710 대원산업 0.028411675 0.54672897 1045887.1524999999
# INFO:tensorflow:Restoring parameters from ./sessions/23910.ckpt
# 1004 23910 대한약품 0.03240583 0.4813084 1185920.9249999998
# INFO:tensorflow:Restoring parameters from ./sessions/17680.ckpt
# 1005 17680 데코앤이 0.015094526 0.47079438 949668.4062499999
# INFO:tensorflow:Restoring parameters from ./sessions/13120.ckpt
# 1006 13120 동원개발 0.054238506 0.53271025 1003810.66525
# INFO:tensorflow:Restoring parameters from ./sessions/33310.ckpt
# 1007 33310 디케이디앤아이 0.031044824 0.47196263 1048068.8154999999
# INFO:tensorflow:Restoring parameters from ./sessions/72870.ckpt
# 1008 72870 메가스터디 0.016593566 0.5642523 945364.98
# INFO:tensorflow:Restoring parameters from ./sessions/6920.ckpt
# 1009 6920 모헨즈 0.02150407 0.47079438 823945.6005000001
# INFO:tensorflow:Restoring parameters from ./sessions/18700.ckpt
# 1010 18700 바른손 0.047052357 0.50116825 939958.7200000001
# INFO:tensorflow:Restoring parameters from ./sessions/6910.ckpt
# 1011 6910 보성파워텍 0.046320576 0.5 867445.3600000002
# INFO:tensorflow:Restoring parameters from ./sessions/42370.ckpt
# 1012 42370 비츠로테크 0.02000006 0.48948598 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/32850.ckpt
# 1013 32850 비트컴퓨터 0.021888683 0.49649534 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/18310.ckpt
# 1014 18310 삼목에스폼 0.04609044 0.5257009 1027438.3275
# INFO:tensorflow:Restoring parameters from ./sessions/54540.ckpt
# 1015 54540 삼영엠텍 0.015137484 0.51752335 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/46390.ckpt
# 1016 46390 삼화네트웍스 0.028450683 0.52102804 937307.3155
# INFO:tensorflow:Restoring parameters from ./sessions/6730.ckpt
# 1017 6730 서부T&D 0.009362702 0.5140187 987861.7825
# INFO:tensorflow:Restoring parameters from ./sessions/15750.ckpt
# 1018 15750 성우하이텍 0.019571595 0.48948598 1021370.99
# INFO:tensorflow:Restoring parameters from ./sessions/13810.ckpt
# 1019 13810 스페코 0.04204723 0.47196263 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/65350.ckpt
# 1020 65350 신성델타테크 0.015478749 0.51285046 998966.23375
# INFO:tensorflow:Restoring parameters from ./sessions/17000.ckpt
# 1021 17000 신원종합개발 0.06325199 0.5070093 910160.7829999999
# INFO:tensorflow:Restoring parameters from ./sessions/36710.ckpt
# 1022 36710 심텍홀딩스 0.02568413 0.52453274 904568.6039999999
# INFO:tensorflow:Restoring parameters from ./sessions/54800.ckpt
# 1023 54800 아이디스홀딩스 0.02190461 0.51635516 1001410.015
# INFO:tensorflow:Restoring parameters from ./sessions/31310.ckpt
# 1024 31310 아이즈비전 0.0042703054 0.5268692 932037.7000000001
# INFO:tensorflow:Restoring parameters from ./sessions/23890.ckpt
# 1025 23890 아트라스BX 0.020451631 0.50934577 967863.43
# INFO:tensorflow:Restoring parameters from ./sessions/1540.ckpt
# 1026 1540 안국약품 0.0378931 0.50584114 884687.5124999998
# INFO:tensorflow:Restoring parameters from ./sessions/53800.ckpt
# 1027 53800 안랩 0.019375393 0.50233644 901116.505
# INFO:tensorflow:Restoring parameters from ./sessions/61040.ckpt
# 1028 61040 알에프텍 0.027407076 0.4848131 1028158.76
# INFO:tensorflow:Restoring parameters from ./sessions/41510.ckpt
# 1029 41510 에스엠 0.026748985 0.46495327 962048.6374999998
# INFO:tensorflow:Restoring parameters from ./sessions/64090.ckpt
# 1030 64090 에프앤리퍼블릭 0.03885295 0.51635516 1442884.96
# INFO:tensorflow:Restoring parameters from ./sessions/54940.ckpt
# 1031 54940 엑사이엔씨 0.012740109 0.4848131 935805.7794999998
# INFO:tensorflow:Restoring parameters from ./sessions/36000.ckpt
# 1032 36000 예림당 0.022870379 0.49182242 1894886.783
# INFO:tensorflow:Restoring parameters from ./sessions/39830.ckpt
# 1033 39830 오로라 0.034048054 0.47429907 1014398.56
# INFO:tensorflow:Restoring parameters from ./sessions/10470.ckpt
# 1034 10470 오리콤 0.046183992 0.49532712 987267.775
# INFO:tensorflow:Restoring parameters from ./sessions/49480.ckpt
# 1035 49480 오픈베이스 0.04760347 0.48948598 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/30530.ckpt
# 1036 30530 원익홀딩스 0.035184488 0.47897196 1119188.03
# INFO:tensorflow:Restoring parameters from ./sessions/12620.ckpt
# 1037 12620 원일특강 0.0363289 0.5443925 1004380.5199999999
# INFO:tensorflow:Restoring parameters from ./sessions/18000.ckpt
# 1038 18000 유니슨 0.024278164 0.49182242 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/69330.ckpt
# 1039 69330 유아이디 0.03638506 0.52102804 1142448.4915
# INFO:tensorflow:Restoring parameters from ./sessions/23410.ckpt
# 1040 23410 유진기업 0.017721584 0.48014018 1059884.692
# INFO:tensorflow:Restoring parameters from ./sessions/33600.ckpt
# 1041 33600 이젠텍 0.05406016 0.48714954 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/16250.ckpt
# 1042 16250 이테크건설 0.042572986 0.49415886 976826.2249999999
# INFO:tensorflow:Restoring parameters from ./sessions/60150.ckpt
# 1043 60150 인선이엔티 0.009276425 0.50233644 1158512.3655
# INFO:tensorflow:Restoring parameters from ./sessions/65530.ckpt
# 1044 65530 전파기지국 0.050393302 0.5373832 971583.7825
# INFO:tensorflow:Restoring parameters from ./sessions/36420.ckpt
# 1045 36420 제이콘텐트리 0.02249743 0.4567757 894796.5869999998
# INFO:tensorflow:Restoring parameters from ./sessions/72020.ckpt
# 1046 72020 중앙백신 0.041109808 0.49415886 924108.9225000001
# INFO:tensorflow:Restoring parameters from ./sessions/65060.ckpt
# 1047 65060 지엔코 0.05364432 0.4647378 899025.5279999999
# INFO:tensorflow:Restoring parameters from ./sessions/13720.ckpt
# 1048 13720 청보산업 0.02197801 0.46845794 971579.2775
# INFO:tensorflow:Restoring parameters from ./sessions/47820.ckpt
# 1049 47820 초록뱀 0.04061234 0.4848131 915757.184
# INFO:tensorflow:Restoring parameters from ./sessions/41960.ckpt
# 1050 41960 코미팜 0.02764556 0.50584114 930324.55
# INFO:tensorflow:Restoring parameters from ./sessions/16600.ckpt
# 1051 16600 큐캐피탈 0.0106475735 0.49182242 1209493.38165
# INFO:tensorflow:Restoring parameters from ./sessions/45520.ckpt
# 1052 45520 크린앤사이언스 0.029831968 0.49182242 594974.2829999999
# INFO:tensorflow:Restoring parameters from ./sessions/23160.ckpt
# 1053 23160 태광 0.010599433 0.5186916 1119522.816
# INFO:tensorflow:Restoring parameters from ./sessions/66700.ckpt
# 1054 66700 테라젠이텍스 0.043403532 0.46845794 939205.1249999999
# INFO:tensorflow:Restoring parameters from ./sessions/45340.ckpt
# 1055 45340 토탈소프트 0.045820106 0.4755877 937683.7952500001
# INFO:tensorflow:Restoring parameters from ./sessions/52290.ckpt
# 1056 52290 트레이스 0.027126618 0.42133814 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/34230.ckpt
# 1057 34230 파라다이스 0.034371577 0.5035047 827474.5375
# INFO:tensorflow:Restoring parameters from ./sessions/43370.ckpt
# 1058 43370 평화정공 0.025981197 0.49299064 1041963.1375000001
# INFO:tensorflow:Restoring parameters from ./sessions/56730.ckpt
# 1059 56730 포스링크 0.024078716 0.50233644 909550.324
# INFO:tensorflow:Restoring parameters from ./sessions/53160.ckpt
# 1060 53160 프리엠스 0.05795831 0.45931283 942085.822
# INFO:tensorflow:Restoring parameters from ./sessions/24850.ckpt
# 1061 24850 피에스엠씨 0.043127898 0.4954792 919983.21645
# INFO:tensorflow:Restoring parameters from ./sessions/4590.ckpt
# 1062 4590 한국가구 0.036321107 0.50934577 958257.3100000002
# INFO:tensorflow:Restoring parameters from ./sessions/34950.ckpt
# 1063 34950 한국기업평가 0.023026895 0.5070093 1091089.46
# INFO:tensorflow:Restoring parameters from ./sessions/53590.ckpt
# 1064 53590 한국테크놀로지 0.019600553 0.5 846001.058
# INFO:tensorflow:Restoring parameters from ./sessions/45100.ckpt
# 1065 45100 한양이엔지 0.03663361 0.53154206 1110260.3850000002
# INFO:tensorflow:Restoring parameters from ./sessions/48410.ckpt
# 1066 48410 현대아이비티 0.05474613 0.49182242 1639429.6212499999
# INFO:tensorflow:Restoring parameters from ./sessions/53660.ckpt
# 1067 53660 현진소재 0.04577325 0.48598132 1000000
# INFO:tensorflow:Restoring parameters from ./sessions/61250.ckpt
# 1068 61250 화일약품 0.030666687 0.47196263 947442.748

# %%
# 엑셀파일로 저장한다.
df_comp_rmses = pd.DataFrame(comp_rmses, columns=['code', 'name', 'rmse', 'direction_error', 'invest_result'])    
#df_comp_rmses = df_comp_rmses.sort_values('invest_result', ascending=False)
save_excel(df_comp_rmses, 'training_invest_result_2.xlsx')
