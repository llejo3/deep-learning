# %%
import zipfile

# %%
fantasy_zip = zipfile.ZipFile('./Stock_Dataset(2017_07_06).zip')
fantasy_zip.extractall('./data')

# %%
import pandas as pd
from pandas import Series, DataFrame
from sklearn import preprocessing
import numpy as np
import tensorflow as tf
import math
#import matplotlib.pyplot as plt
#import itertools

# %%
# !pip install xlrd
# Out:
# Collecting xlrd
#   Using cached https://files.pythonhosted.org/packages/07/e6/e95c4eec6221bfd8528bcc4ea252a850bffcc4be88ebc367e23a1a84b0bb/xlrd-1.1.0-py2.py3-none-any.whl
# mxnet-cu80 1.1.0 has requirement numpy<=1.13.3, but you'll have numpy 1.14.3 which is incompatible.
# Installing collected packages: xlrd
# Successfully installed xlrd-1.1.0

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
# Collecting jdcal (from openpyxl)
#   Using cached https://files.pythonhosted.org/packages/a0/38/dcf83532480f25284f3ef13f8ed63e03c58a65c9d3ba2a6a894ed9497207/jdcal-1.4-py2.py3-none-any.whl
# Collecting et-xmlfile (from openpyxl)
# mxnet-cu80 1.1.0 has requirement numpy<=1.13.3, but you'll have numpy 1.14.3 which is incompatible.
# Installing collected packages: jdcal, et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.0.1 jdcal-1.4 openpyxl-2.5.4

# %%
### 메소드 정의 
# 상세 데이터를 가져온다.
def get_stock_datail(comp_code) :
    code = format(comp_code, "06d");
    return pd.read_csv('./data/' + code + '.csv')

# matrix 데이터로 변경한다.
def to_ndarray(cols_data) :
    if isinstance(cols_data, Series):
        return np.reshape(list(cols_data), (-1,1))
    elif isinstance(cols_data, DataFrame):
        return cols_data.as_matrix()

# 컬럼을 스케일링을 시킨다.
def get_scaled_cols(data, column_name) :
    scale_data = to_ndarray(data[column_name])
    scaler = preprocessing.MinMaxScaler()
    return scaler.fit_transform(scale_data);

# 데이터를 스케일링 시킨다.
def get_scaled_data(data) :
    scaled_data = data.copy()
    scaled_data['Close'] = get_scaled_cols(scaled_data, 'Close')
    scaled_data['Open'] = get_scaled_cols(scaled_data, 'Open')
    scaled_data['High'] = get_scaled_cols(scaled_data, 'High')
    scaled_data['Low'] = get_scaled_cols(scaled_data, 'Low')
    scaled_data['Volume'] = get_scaled_cols(scaled_data, 'Volume')
    return scaled_data;

# RNN을 위한 데이터로 만든다. 
def get_dataXY(data, train_params) :
    x = to_ndarray(data[['Open', 'High', 'Low', 'Volume', 'Close']])
    y = to_ndarray(data['Close'])
    
    dataX = []
    dataY = []
    seq_length = train_params['seq_length']
    for i in range(0, len(y) - seq_length):
        _x = x[i:i + seq_length]
        _y = y[i + seq_length] # Next close price
        #print(_x, "->", _y)
        dataX.append(_x)
        dataY.append(_y)
    return dataX, dataY, y

# train 및 test 데이터로 나눈다.
def split_train_test(dataX, dataY, train_params, data, y) :
    invest_count = train_params['invest_count']
    seq_length = train_params['seq_length']
    data_count = len(dataY);
    train_size = int(data_count * train_params['train_percent'] / 100)
    train_last = data_count-invest_count;
    
    trainX = np.array(dataX[0:train_size])
    testX = np.array(dataX[train_size:train_last])
    investX = np.array(dataX[train_last:data_count])
    
    trainY = np.array(dataY[0:train_size])
    testY = np.array(dataY[train_size:train_last])
    investY = np.array(dataY[train_last:data_count])
    
    trainCloses = np.array( y[seq_length-1:train_size+seq_length-1])
    testCloses = np.array(dataY[train_size-1:train_last-1])
    investCloses = np.array(dataY[train_last-1:data_count-1])
    investRealCloses = np.array(data['Close'][train_last-1+seq_length:data_count-1+seq_length].values)
    
    return {
        'trainX': trainX, 'trainY': trainY, 'trainCloses': trainCloses,
        'testX': testX, 'testY': testY, 'testCloses' : testCloses,
        'investX': investX,'investY': investY, 'investCloses': investCloses, 'investRealCloses': investRealCloses
    }

# train, test데이터로 만든다.
def get_train_test(data, train_params) :
    scaled_data = get_scaled_data(data)
    dataX, dataY, y = get_dataXY(scaled_data, train_params)
    return split_train_test(dataX, dataY, train_params, data, y)

# 텐스플로우 변수관계 그래프롤 그린다.
def draw_graph(train_params) :
    seq_length = train_params['seq_length']
    data_dim = train_params['data_dim']
    hidden_dims = train_params['hidden_dims']
    
    tf.reset_default_graph()
    X = tf.placeholder(tf.float32, [None, seq_length, data_dim])
    X_closes = tf.placeholder(tf.float32, [None, 1])
    Y = tf.placeholder(tf.float32, [None, 1])
    output_keep_prob = tf.placeholder(tf.float32)
    
    cells = []
    for n in hidden_dims :
        cell = tf.contrib.rnn.BasicLSTMCell(num_units=n, activation=tf.tanh)
        dropout_cell = tf.contrib.rnn.DropoutWrapper(cell, output_keep_prob=output_keep_prob)
        cells.append(dropout_cell)
    stacked_rnn_cell = tf.nn.rnn_cell.MultiRNNCell(cells)
    outputs, _states = tf.nn.dynamic_rnn(stacked_rnn_cell, X, dtype=tf.float32) 
    Y_pred = tf.contrib.layers.fully_connected(
        outputs[:, -1], train_params['output_dim'], activation_fn=None)  # We use the last cell's output

    # cost/loss
    #not_equal = tf.cast(tf.not_equal(tf.sign(X_closes-Y), tf.sign(X_closes-Y_pred)), tf.float32)
    #loss = tf.reduce_sum(tf.square(Y_pred - Y) + not_equal)
    loss = tf.reduce_sum(tf.square(1-(1+Y_pred-X_closes)/(1+Y-X_closes)))
        
    optimizer = tf.train.AdamOptimizer(train_params['learning_rate'])
    train = optimizer.minimize(loss)

    # RMSE
    targets = tf.placeholder(tf.float32, [None, 1])
    predictions = tf.placeholder(tf.float32, [None, 1])
    #rmse = tf.sqrt(tf.reduce_mean(tf.square(targets - predictions)))
    rmse = tf.sqrt(tf.reduce_mean(tf.square(1-(1+predictions-X_closes)/(1+targets-X_closes))))
    #direction_error = tf.reduce_mean(
    #    tf.cast(tf.not_equal(tf.sign(X_closes-targets), tf.sign(X_closes-predictions)), tf.float32))
    
    return {
        'X': X,
        'Y': Y,
        'output_keep_prob': output_keep_prob,
        'train': train,
        'loss' : loss,
        'Y_pred': Y_pred,
        'targets': targets,
        'rmse' : rmse,
        'predictions': predictions,
        'X_closes' : X_closes,
        #'direction_error' : direction_error
    }

def draw_plot(rmse_vals, test_predict, testY, train_params, comp_name) :
    
    print('rmse_vals : ', rmse_vals[len(rmse_vals)-1])
    plt.figure(1)
    plt.plot(rmse_vals, 'gold')
    plt.xlabel('Epoch(x100)')
    plt.ylabel('Root Mean Square Error')
    plt.title(comp_name)

    plt.figure(2)
    plt.plot(testY, 'r')
    plt.plot(test_predict, 'b')
    plt.xlabel('Time Period')
    plt.ylabel('Stock Price')
    plt.title(comp_name)
    plt.show()

# 학습을 시킨다.
def let_training(data_params, train_params, graph_params, comp_code, comp_name) :
    X = graph_params['X']
    Y = graph_params['Y']
    output_keep_prob = graph_params['output_keep_prob']
    train = graph_params['train']
    loss = graph_params['loss']
    trainX = data_params['trainX']
    trainY = data_params['trainY']
    testX = data_params['testX']
    testY = data_params['testY']
    trainCloses = data_params['trainCloses']
    testCloses = data_params['testCloses']
    
    Y_pred = graph_params['Y_pred']
    targets = graph_params['targets']
    rmse = graph_params['rmse']
    predictions = graph_params['predictions']
    X_closes = graph_params['X_closes']
    loss_up_count = train_params['loss_up_count']
    dropout_keep = train_params['dropout_keep']
    iterations = train_params['iterations']
    rmse_max = train_params['rmse_max']
    
    saver = tf.train.Saver()
    
    with tf.Session() as sess:
        init = tf.global_variables_initializer()
        sess.run(init)

        # Training step
        min_rmse_val = 999999
        less_cnt = 0
        train_count = 0
        #rmse_vals = []
        
        for i in range(iterations[1]):
            _, step_loss = sess.run([train, loss], feed_dict={X: trainX, Y: trainY, X_closes: trainCloses, output_keep_prob: dropout_keep})
            if (i < iterations[0]) :
                continue
            
            test_predict = sess.run(Y_pred, feed_dict={X: testX, output_keep_prob: 1.0})
            rmse_val = sess.run(rmse, feed_dict={targets: testY, predictions: test_predict, X_closes: testCloses}) 
            #rmse_vals.append(rmse_val)
            if rmse_val < min_rmse_val :
                tf.add_to_collection("X", X)
                tf.add_to_collection("X_closes", X_closes)
                tf.add_to_collection("Y", Y)
                tf.add_to_collection("train", train)
                tf.add_to_collection("Y_pred", Y_pred)
                tf.add_to_collection("output_keep_prob", output_keep_prob)
                saver.save(sess, "./sessions/" + str(comp_code) + ".ckpt")
                less_cnt = 0
                train_count = i;
                max_test_predict, min_rmse_val, = test_predict, rmse_val
            else :
                less_cnt += 1
            if less_cnt > loss_up_count and rmse_max > min_rmse_val:
                #print(less_cnt, rmse_val, train_count, i)
                break
        #draw_plot(rmse_vals, max_test_predict, testY, train_params, comp_name) 
        return max_test_predict, min_rmse_val, train_count 

# 그래프를 그리고 학습을 시킨다.    
def let_leaning(data_params, train_params, comp_code, comp_name):
    graph_params = draw_graph(train_params)
    return let_training(data_params, train_params, graph_params, comp_code, comp_name)

def to_dataFrame(data, columns) :
    return pd.DataFrame(data, columns=columns)

# excel로 저장한다.
def save_excel(df_data, file_name):
    writer = pd.ExcelWriter(file_name)
    df_data.to_excel(writer,'Sheet1', index=False)
    writer.save()

# 예측 값에 따라 매수 매도를 실행한다.    
def let_invest_money(invest_predict, now_scaled_close, now_close, train_params, now_money, now_stock_cnt) :
    seq_length = train_params['seq_length']
    data_dim = train_params['data_dim']
    fee_percent = train_params['fee_percent']
    invest_min_percent = train_params['invest_min_percent']
    
    ratio = (invest_predict - now_scaled_close) /now_scaled_close * 100
    
    if ratio > invest_min_percent :
        cnt = math.floor(now_money/now_close)
        if cnt > 0 :
            fee = now_close * fee_percent/100
            now_money -= (now_close + fee) * cnt
            now_stock_cnt += cnt
    elif ratio < -invest_min_percent :
        if now_stock_cnt > 0 :
            now_money += to_money(now_close, now_stock_cnt, train_params)
            now_stock_cnt = 0
    #print(now_money, now_stock_cnt, now_scaled_close, invest_predict, data_params['testY'])
    return now_money, now_stock_cnt

# 주식매도를 해서 돈으로 바꾼다.
def to_money(now_stock_cnt, now_close, train_params) :
    money = 0
    if now_stock_cnt > 0 :
        fee_percent = train_params['fee_percent'] 
        tax_percent = train_params['tax_percent']
        
        fee = now_close * fee_percent/100
        tax = now_close * tax_percent/100
        money = (now_close - (fee + tax)) * now_stock_cnt
    return money
    
# 학습 후 모의 주식 거래를 한다.
def let_invest(row, train_params, data_params, train_cnt):
    comp_code = row['종목코드']
    invest_count = train_params['invest_count']
    invest_money = train_params['invest_money']
    dropout_keep = train_params['dropout_keep']
    
    investX = data_params['investX']
    investCloses = data_params['investCloses']
    investRealCloses = data_params['investRealCloses']
    investX = data_params['investX']
    investY = data_params['investY']
    testX = data_params['testX']
    testY = data_params['testY']
    testCloses = data_params['testCloses']
    #print(investRealCloses)
    
    now_stock_cnt = 0
    saver = tf.train.Saver()
    with tf.Session() as sess:
        init = tf.global_variables_initializer()
        sess.run(init)
        
        saver.restore(sess, "./sessions/" + str(comp_code) + ".ckpt") 
        X = tf.get_collection('X')[0]
        X_closes = tf.get_collection('X_closes')[0]
        Y = tf.get_collection('Y')[0]
        train = tf.get_collection('train')[0]
        Y_pred = tf.get_collection('Y_pred')[0]
        output_keep_prob = tf.get_collection('output_keep_prob')[0]
        
        for i in range(int(train_cnt/10)):
            sess.run(train, feed_dict={X: testX, Y: testY, X_closes: testCloses, output_keep_prob: dropout_keep})
        
        for i in range(invest_count) :
            np.array([1, 2, 3], ndmin=2)
            invest_predicts = sess.run(Y_pred, feed_dict={X: investX[i:i+1], output_keep_prob: 1.0})
            
            invest_predict = invest_predicts[0][0];
            now_scaled_close = investCloses[0][0]
            now_close = investRealCloses[i]
            #print(invest_predict, now_scaled_close, now_close)
            invest_money, now_stock_cnt = let_invest_money(invest_predict, now_scaled_close, now_close,
                                                           train_params, invest_money, now_stock_cnt)
            for i in range(int(train_cnt/100)):
                sess.run(train, feed_dict={X: investX[i:i+1], Y: investY[i:i+1], X_closes: investCloses[i:i+1], 
                                           output_keep_prob: dropout_keep})
            #break
        invest_money += to_money(now_stock_cnt, now_close, train_params)
    #print(now_money)
    return invest_money

# %%
# 파라미터 정의 
# train Parameters
train_params = {
    'seq_length' : 5, # 시퀀스 갯수
    'data_dim' : 5,    # 입력 데이터 갯수
    'hidden_dims' : [128, 96, 64],  # 히든 레이어 갯수 
    'dropout_keep' : 0.8, # dropout 
    'output_dim' : 1,  # 출력 데이터 갯수
    'learning_rate' : 0.0001, 
    'iterations' : [30, 120],  # 최소, 최대 훈련 반복횟수
    'rmse_max' : 0.049,
    'train_percent' : 70.0, # 훈련 데이터 퍼센트
    'loss_up_count' : 12, # early stopping
    'invest_count' : 50,  # 투자 횟수
    'invest_money' : 1000000, # 각 주식에 모의투자할 금액
    'fee_percent' : 0.015, # 투자시 발생하는 수수료
    'tax_percent' : 0.5,   # 매도시 발생하는 세금
    'invest_min_percent' : 0.6 # 투자를 하는 최소 간격 퍼센트 
};

# %%
# 주식회사 데이터
corporations = pd.read_excel('./corporations.xlsx')

# %%
stock_corps = corporations.query("상장일<'2005-01-01'  ")[['회사명', '종목코드']]
print(len(stock_corps))
# Out:
# 1068

# %%
# 주식 종목들을 가져와서 학습을 시킨다.
comp_rmses = []
no = 1;
print('no', 'code', 'name', 'rmse', 'invest_result', 'train_cnt')
for idx, row in stock_corps.iterrows():
    #if no < 15 :
    #    no += 1
    #    continue
    comp_code = row['종목코드']
    data = get_stock_datail(comp_code)
    data_params = get_train_test(data, train_params)
    _, rmse_val, train_cnt = let_leaning(data_params, train_params, comp_code, row['회사명'])
    
    now_money = let_invest(row, train_params, data_params, train_cnt)
    print(no, comp_code, row['회사명'], rmse_val, now_money, train_cnt)
    comp_rmses.append([no, comp_code, row['회사명'], rmse_val, now_money, train_cnt])
    no += 1
# Out:
# no code name rmse invest_result train_cnt
# /opt/venv/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /opt/venv/lib/python3.6/site-packages/ipykernel_launcher.py:12: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if sys.path[0] == '':
# INFO:tensorflow:Restoring parameters from ./sessions/1460.ckpt
# 1 1460 BYC 0.1255814 991087.8500000001 119
# INFO:tensorflow:Restoring parameters from ./sessions/79160.ckpt
# 2 79160 CJ CGV 0.05155008 1000000 109
# INFO:tensorflow:Restoring parameters from ./sessions/5830.ckpt
# 3 5830 DB손해보험 0.026662242 1000000 77
# INFO:tensorflow:Restoring parameters from ./sessions/69730.ckpt
# 4 69730 DSR제강 0.052121233 865171.8550000001 119
# INFO:tensorflow:Restoring parameters from ./sessions/9440.ckpt
# 5 9440 KC그린홀딩스 0.022932425 883278.92 47
# INFO:tensorflow:Restoring parameters from ./sessions/1940.ckpt
# 6 1940 KISCO홀딩스 0.03029946 1187526.775 64
# INFO:tensorflow:Restoring parameters from ./sessions/23150.ckpt
# 7 23150 MH에탄올 0.020541461 1000000 66
# INFO:tensorflow:Restoring parameters from ./sessions/34310.ckpt
# 8 34310 NICE 0.035440963 907234.5350000003 45
# INFO:tensorflow:Restoring parameters from ./sessions/36530.ckpt
# 9 36530 S&T홀딩스 0.030738382 1079336.3725 63
# INFO:tensorflow:Restoring parameters from ./sessions/17670.ckpt
# 10 17670 SK텔레콤 0.04255186 1024251.0249999999 74
# INFO:tensorflow:Restoring parameters from ./sessions/12200.ckpt
# 11 12200 계양전기 0.10445051 953289.0584999999 119
# INFO:tensorflow:Restoring parameters from ./sessions/1290.ckpt
# 12 1290 골든브릿지증권 0.03498478 1525493.6469999999 30
# INFO:tensorflow:Restoring parameters from ./sessions/24110.ckpt
# 13 24110 기업은행 0.02790699 1163943.5950000002 64
# INFO:tensorflow:Restoring parameters from ./sessions/4540.ckpt
# 14 4540 깨끗한나라 0.052618336 969784.8 63
# INFO:tensorflow:Restoring parameters from ./sessions/1260.ckpt
# 15 1260 남광토건 0.022208476 828818.3025000001 31
# INFO:tensorflow:Restoring parameters from ./sessions/25860.ckpt
# 16 25860 남해화학 0.020469353 1138954.7804999999 53
# INFO:tensorflow:Restoring parameters from ./sessions/58730.ckpt
# 17 58730 다스코 0.062249694 1017717.468 72
# INFO:tensorflow:Restoring parameters from ./sessions/6370.ckpt
# 18 6370 대구백화점 0.036658276 998523.89 76
# INFO:tensorflow:Restoring parameters from ./sessions/3540.ckpt
# 19 3540 대신증권 0.03040063 1107324.7825000002 43
# INFO:tensorflow:Restoring parameters from ./sessions/1130.ckpt
# 20 1130 대한제분 0.042524066 1002572.125 80
# INFO:tensorflow:Restoring parameters from ./sessions/3490.ckpt
# 21 3490 대한항공 0.057444535 1217997.34 56
# INFO:tensorflow:Restoring parameters from ./sessions/5880.ckpt
# 22 5880 대한해운 0.009958661 1561551.2974999999 35
# INFO:tensorflow:Restoring parameters from ./sessions/69460.ckpt
# 23 69460 대호에이엘 0.041498728 1092449.9749999999 66
# INFO:tensorflow:Restoring parameters from ./sessions/24900.ckpt
# 24 24900 덕양산업 0.1707073 988079.5989999999 119
# INFO:tensorflow:Restoring parameters from ./sessions/24090.ckpt
# 25 24090 디씨엠 0.039655086 1013366.6874999999 76
# INFO:tensorflow:Restoring parameters from ./sessions/4990.ckpt
# 26 4990 롯데지주 0.11927254 947816.4 66
# INFO:tensorflow:Restoring parameters from ./sessions/11170.ckpt
# 27 11170 롯데케미칼 0.033615816 944282.2 77
# INFO:tensorflow:Restoring parameters from ./sessions/27740.ckpt
# 28 27740 마니커 0.03651952 975264.6157 30
# INFO:tensorflow:Restoring parameters from ./sessions/8560.ckpt
# 29 8560 메리츠종금증권 0.03785369 1341278.75325 59
# INFO:tensorflow:Restoring parameters from ./sessions/9680.ckpt
# 30 9680 모토닉 0.015998354 1122808.0690000001 33
# INFO:tensorflow:Restoring parameters from ./sessions/2760.ckpt
# 31 2760 보락 0.04740492 1000000 57
# INFO:tensorflow:Restoring parameters from ./sessions/3850.ckpt
# 32 3850 보령제약 0.09737097 969426.9575 119
# INFO:tensorflow:Restoring parameters from ./sessions/79660.ckpt
# 33 79660 사조해표 0.062464282 1042323.9774999999 77
# INFO:tensorflow:Restoring parameters from ./sessions/2170.ckpt
# 34 2170 삼양통상 0.11088761 1000000 119
# INFO:tensorflow:Restoring parameters from ./sessions/11230.ckpt
# 35 11230 삼화전자공업 0.03349673 1000000 41
# INFO:tensorflow:Restoring parameters from ./sessions/41650.ckpt
# 36 41650 상신브레이크 0.041884225 1007259.4900000001 119
# INFO:tensorflow:Restoring parameters from ./sessions/58650.ckpt
# 37 58650 세아홀딩스 0.035127804 1099320.9 76
# INFO:tensorflow:Restoring parameters from ./sessions/33530.ckpt
# 38 33530 세종공업 0.0330195 955717.9169999998 81
# INFO:tensorflow:Restoring parameters from ./sessions/4430.ckpt
# 39 4430 송원산업 0.04808687 1017105.8999999999 75
# INFO:tensorflow:Restoring parameters from ./sessions/2870.ckpt
# 40 2870 신풍제지 0.03353548 1000000 56
# INFO:tensorflow:Restoring parameters from ./sessions/1770.ckpt
# 41 1770 신화실업 0.07017266 941837.5799999998 119
# INFO:tensorflow:Restoring parameters from ./sessions/4080.ckpt
# 42 4080 신흥 0.037842415 955333.6200000001 56
# INFO:tensorflow:Restoring parameters from ./sessions/3560.ckpt
# 43 3560 아이에이치큐 0.027957575 1159933.2397500002 48
# INFO:tensorflow:Restoring parameters from ./sessions/12750.ckpt
# 44 12750 에스원 0.08033633 987863.2499999999 67
# INFO:tensorflow:Restoring parameters from ./sessions/25530.ckpt
# 45 25530 에스제이엠홀딩스 0.054692622 1000000 71
# INFO:tensorflow:Restoring parameters from ./sessions/7310.ckpt
# 46 7310 오뚜기 0.047572244 987785.3 100
# INFO:tensorflow:Restoring parameters from ./sessions/11330.ckpt
# 47 11330 유니켐 0.25202194 1000000 66
# INFO:tensorflow:Restoring parameters from ./sessions/1200.ckpt
# 48 1200 유진증권 0.047594197 1235242.677 70
# INFO:tensorflow:Restoring parameters from ./sessions/7660.ckpt
# 49 7660 이수페타시스 0.038035646 984182.3089999999 72
# INFO:tensorflow:Restoring parameters from ./sessions/23800.ckpt
# 50 23800 인지컨트롤스 0.019872805 1114032.42875 58
# INFO:tensorflow:Restoring parameters from ./sessions/3200.ckpt
# 51 3200 일신방직 0.064708345 998997.4 119
# INFO:tensorflow:Restoring parameters from ./sessions/8500.ckpt
# 52 8500 일정실업 0.045406748 1000000 77
# INFO:tensorflow:Restoring parameters from ./sessions/20760.ckpt
# 53 20760 일진디스플 0.083678745 1331268.885 54
# INFO:tensorflow:Restoring parameters from ./sessions/30000.ckpt
# 54 30000 제일기획 0.030361865 1005521.23 30
# INFO:tensorflow:Restoring parameters from ./sessions/35000.ckpt
# 55 35000 지투알 0.038590427 1000000 58
# INFO:tensorflow:Restoring parameters from ./sessions/33780.ckpt
# 56 33780 케이티앤지 0.035762466 1021225.3750000001 76
# INFO:tensorflow:Restoring parameters from ./sessions/5420.ckpt
# 57 5420 코스모화학 0.03268959 1965300.04 56
# INFO:tensorflow:Restoring parameters from ./sessions/12170.ckpt
# 58 12170 키위미디어그룹 0.034895618 1302651.328 43
# INFO:tensorflow:Restoring parameters from ./sessions/7980.ckpt
# 59 7980 태평양물산 0.030203503 976498.591 30
# INFO:tensorflow:Restoring parameters from ./sessions/58430.ckpt
# 60 58430 포스코강판 0.053074155 1292384.6375000002 119
# INFO:tensorflow:Restoring parameters from ./sessions/7630.ckpt
# 61 7630 폴루스바이오팜 0.052627593 1000000 102
# INFO:tensorflow:Restoring parameters from ./sessions/5430.ckpt
# 62 5430 한국공항 0.052950043 1000000 119
# INFO:tensorflow:Restoring parameters from ./sessions/2200.ckpt
# 63 2200 한국수출포장공업 0.02664042 980512.3799999999 74
# INFO:tensorflow:Restoring parameters from ./sessions/970.ckpt
# 64 970 한국주철관공업 0.20465061 1108630.072 119
# INFO:tensorflow:Restoring parameters from ./sessions/9240.ckpt
# 65 9240 한샘 0.044976555 955255.8 80
# INFO:tensorflow:Restoring parameters from ./sessions/16450.ckpt
# 66 16450 한세예스24홀딩스 0.035531733 976015.9 111
# INFO:tensorflow:Restoring parameters from ./sessions/4960.ckpt
# 67 4960 한신공영 0.042676702 1042229.6050000001 62
# INFO:tensorflow:Restoring parameters from ./sessions/4310.ckpt
# 68 4310 현대약품 0.021370362 1000000 33
# INFO:tensorflow:Restoring parameters from ./sessions/8770.ckpt
# 69 8770 호텔신라 0.04741421 900879.4400000001 111
# INFO:tensorflow:Restoring parameters from ./sessions/10690.ckpt
# 70 10690 화신 0.034289416 989924.72 63
# INFO:tensorflow:Restoring parameters from ./sessions/5010.ckpt
# 71 5010 휴스틸 0.040723477 970973.6225 58
# INFO:tensorflow:Restoring parameters from ./sessions/51500.ckpt
# 72 51500 CJ프레시웨이 0.040186785 1047128.3750000001 105
# INFO:tensorflow:Restoring parameters from ./sessions/32860.ckpt
# 73 32860 GMR 머티리얼즈 0.059882518 1043060.3082 41
# INFO:tensorflow:Restoring parameters from ./sessions/36670.ckpt
# 74 36670 KCI 0.15838598 960476.533 119
# INFO:tensorflow:Restoring parameters from ./sessions/60370.ckpt
# 75 60370 KT서브마린 0.021683183 985634.7557499999 41
# INFO:tensorflow:Restoring parameters from ./sessions/53290.ckpt
# 76 53290 NE능률 0.046488762 973623.4215 65
# INFO:tensorflow:Restoring parameters from ./sessions/36120.ckpt
# 77 36120 SCI평가정보 0.14256845 1058196.69875 119
# INFO:tensorflow:Restoring parameters from ./sessions/40610.ckpt
# 78 40610 SG&G 0.067750886 987220.8369999999 119
# INFO:tensorflow:Restoring parameters from ./sessions/36490.ckpt
# 79 36490 SK머티리얼즈 0.037641343 1042932.45 119
# INFO:tensorflow:Restoring parameters from ./sessions/38530.ckpt
# 80 38530 골드퍼시픽 0.049444996 10986577.580000002 47
# INFO:tensorflow:Restoring parameters from ./sessions/14200.ckpt
# 81 14200 광림 0.06648371 1014002.9454999999 116
# INFO:tensorflow:Restoring parameters from ./sessions/53270.ckpt
# 82 53270 구영테크 0.040669665 1000000 77
# INFO:tensorflow:Restoring parameters from ./sessions/6050.ckpt
# 83 6050 국영지앤엠 0.039105885 1074092.21 50
# INFO:tensorflow:Restoring parameters from ./sessions/64260.ckpt
# 84 64260 다날 0.03573241 918506.1124999999 61
# INFO:tensorflow:Restoring parameters from ./sessions/39560.ckpt
# 85 39560 다산네트웍스 0.042353347 921048.0150000001 49
# INFO:tensorflow:Restoring parameters from ./sessions/4780.ckpt
# 86 4780 대륙제관 0.026022281 986413.4450000001 62
# INFO:tensorflow:Restoring parameters from ./sessions/3310.ckpt
# 87 3310 대주산업 0.025301723 1000000 80
# INFO:tensorflow:Restoring parameters from ./sessions/21040.ckpt
# 88 21040 대호피앤씨 0.024421422 1069686.95125 40
# INFO:tensorflow:Restoring parameters from ./sessions/23790.ckpt
# 89 23790 동일철강 0.006226003 1011127.6765 90
# INFO:tensorflow:Restoring parameters from ./sessions/33430.ckpt
# 90 33430 디에스티 0.092748456 1000000 36
# INFO:tensorflow:Restoring parameters from ./sessions/66900.ckpt
# 91 66900 디에이피 0.022777624 962028.309 76
# INFO:tensorflow:Restoring parameters from ./sessions/68930.ckpt
# 92 68930 디지털대성 0.03162978 974654.848 62
# INFO:tensorflow:Restoring parameters from ./sessions/50120.ckpt
# 93 50120 라이브플렉스 0.016701685 781918.7072500001 42
# INFO:tensorflow:Restoring parameters from ./sessions/1810.ckpt
# 94 1810 무림SP 0.0210503 1060365.4 38
# INFO:tensorflow:Restoring parameters from ./sessions/59090.ckpt
# 95 59090 미코 0.030082695 996100.7025 46
# INFO:tensorflow:Restoring parameters from ./sessions/35620.ckpt
# 96 35620 바른손이앤에이 0.038852323 990936.594 119
# INFO:tensorflow:Restoring parameters from ./sessions/66980.ckpt
# 97 66980 브레인콘텐츠 0.03144999 1022070.8144999999 59
# INFO:tensorflow:Restoring parameters from ./sessions/65450.ckpt
# 98 65450 빅텍 0.045586992 1000000 48
# INFO:tensorflow:Restoring parameters from ./sessions/23600.ckpt
# 99 23600 삼보판지 0.018826168 990349.765 30
# INFO:tensorflow:Restoring parameters from ./sessions/38500.ckpt
# 100 38500 삼표시멘트 0.046752375 987128.677 71
# INFO:tensorflow:Restoring parameters from ./sessions/14620.ckpt
# 101 14620 성광벤드 0.046299852 1062948.83 57
# INFO:tensorflow:Restoring parameters from ./sessions/39310.ckpt
# 102 39310 세중 0.020026213 865996.5812499999 53
# INFO:tensorflow:Restoring parameters from ./sessions/43100.ckpt
# 103 43100 솔고바이오 0.07314591 902844.1034 119
# INFO:tensorflow:Restoring parameters from ./sessions/48870.ckpt
# 104 48870 시너지이노베이션 0.045746624 762912.6092500001 34
# INFO:tensorflow:Restoring parameters from ./sessions/1000.ckpt
# 105 1000 신라섬유 0.13463123 946259.55 119
# INFO:tensorflow:Restoring parameters from ./sessions/56700.ckpt
# 106 56700 신화인터텍 0.03026825 1000000 40
# INFO:tensorflow:Restoring parameters from ./sessions/10280.ckpt
# 107 10280 쌍용정보통신 0.050705206 1000000 119
# INFO:tensorflow:Restoring parameters from ./sessions/60590.ckpt
# 108 60590 씨티씨바이오 0.03490415 936254.3269999999 72
# INFO:tensorflow:Restoring parameters from ./sessions/13990.ckpt
# 109 13990 아가방컴퍼니 0.038487524 850482.7965 55
# INFO:tensorflow:Restoring parameters from ./sessions/36010.ckpt
# 110 36010 아비코전자 0.035331137 1028490.6115 72
# INFO:tensorflow:Restoring parameters from ./sessions/67160.ckpt
# 111 67160 아프리카TV 0.091891214 1000000 119
# INFO:tensorflow:Restoring parameters from ./sessions/43340.ckpt
# 112 43340 에쎈테크 0.061249677 1000000 46
# INFO:tensorflow:Restoring parameters from ./sessions/28300.ckpt
# 113 28300 에이치엘비 0.04840107 1000000 82
# INFO:tensorflow:Restoring parameters from ./sessions/45660.ckpt
# 114 45660 에이텍 0.07788108 1296648.9375 119
# INFO:tensorflow:Restoring parameters from ./sessions/38110.ckpt
# 115 38110 에코플라스틱 0.028074581 1032043.531 57
# INFO:tensorflow:Restoring parameters from ./sessions/31860.ckpt
# 116 31860 엔에스엔 0.045294393 1068426.865 95
# INFO:tensorflow:Restoring parameters from ./sessions/7530.ckpt
# 117 7530 영신금속 0.035974912 1008746.4649999999 46
# INFO:tensorflow:Restoring parameters from ./sessions/57030.ckpt
# 118 57030 와이비엠넷 0.03814104 931513.1777499999 30
# INFO:tensorflow:Restoring parameters from ./sessions/8370.ckpt
# 119 8370 원풍 0.0592006 1000000 69
# INFO:tensorflow:Restoring parameters from ./sessions/69080.ckpt
# 120 69080 웹젠 0.08888785 976015.9000000001 119
# INFO:tensorflow:Restoring parameters from ./sessions/54930.ckpt
# 121 54930 유신 0.052190237 1000000 41
# INFO:tensorflow:Restoring parameters from ./sessions/39020.ckpt
# 122 39020 이건홀딩스 0.025921226 967246.8039999999 43
# INFO:tensorflow:Restoring parameters from ./sessions/33110.ckpt
# 123 33110 이디 0.05515385 860910.4564999999 76
# INFO:tensorflow:Restoring parameters from ./sessions/52190.ckpt
# 124 52190 이에스에이 0.07295424 697311.7232499999 119
# INFO:tensorflow:Restoring parameters from ./sessions/41830.ckpt
# 125 41830 인바디 0.0486559 994768.9 98
# INFO:tensorflow:Restoring parameters from ./sessions/49070.ckpt
# 126 49070 인탑스 0.05041281 965475.7899999999 59
# INFO:tensorflow:Restoring parameters from ./sessions/65620.ckpt
# 127 65620 제낙스 0.046031173 943384.445 91
# INFO:tensorflow:Restoring parameters from ./sessions/33290.ckpt
# 128 33290 코웰패션 0.144722 1113340.33 73
# INFO:tensorflow:Restoring parameters from ./sessions/15710.ckpt
# 129 15710 코콤 0.21706769 960181.7039999999 119
# INFO:tensorflow:Restoring parameters from ./sessions/64760.ckpt
# 130 64760 티씨케이 0.053778403 1251005.1600000001 119
# INFO:tensorflow:Restoring parameters from ./sessions/47310.ckpt
# 131 47310 파워로직스 0.021862553 1000000 44
# INFO:tensorflow:Restoring parameters from ./sessions/49120.ckpt
# 132 49120 파인디앤씨 0.09640406 1000000 119
# INFO:tensorflow:Restoring parameters from ./sessions/32800.ckpt
# 133 32800 판타지오 0.03398823 942942.7997500001 117
# INFO:tensorflow:Restoring parameters from ./sessions/3670.ckpt
# 134 3670 포스코켐텍 0.080222085 1008250.0999999999 119
# INFO:tensorflow:Restoring parameters from ./sessions/53610.ckpt
# 135 53610 프로텍 0.030622527 927208.6375 80
# INFO:tensorflow:Restoring parameters from ./sessions/51380.ckpt
# 136 51380 피씨디렉트 0.044703465 1058213.313 119
# INFO:tensorflow:Restoring parameters from ./sessions/7770.ckpt
# 137 7770 한일화학 0.060211744 966124.64 119
# INFO:tensorflow:Restoring parameters from ./sessions/66110.ckpt
# 138 66110 한프 0.06315339 935025.2924999999 119
# INFO:tensorflow:Restoring parameters from ./sessions/39010.ckpt
# 139 39010 현대통신 0.08872702 1000000 119
# INFO:tensorflow:Restoring parameters from ./sessions/60560.ckpt
# 140 60560 홈센타홀딩스 0.03217533 1000000 41
# INFO:tensorflow:Restoring parameters from ./sessions/6840.ckpt
# 141 6840 AK홀딩스 0.10141911 949628.835 119
# INFO:tensorflow:Restoring parameters from ./sessions/1040.ckpt
# 142 1040 CJ 0.10250622 1007440.375 119

# %%
# 엑셀파일로 저장한다.
df_comp_rmses = pd.DataFrame(comp_rmses, columns=['no', 'code', 'name', 'rmse', 'invest_result', 'train_cnt'])    
save_excel(df_comp_rmses, 'training_invest_result_try13.xlsx')
